# %% [markdown]
# ## This notebook implements two constrained training scheme based on Newton's method.
#
# ### Newton's method
#
# ---
#
# ### Given $g: \mathbb{R}^N\rightarrow \mathbb{R}^k$, $x\in \mathbb{R}^N$, $v \in \mathbb{R}^{N\times k}$ find $\lambda\in \mathbb{R}^k$, such that
# $$
# \begin{aligned}
#    g(x + \tau v \lambda) = 0
#    \end{aligned}
# $$
#
# Netwon's method:
#
# $$
# \lambda_{n+1} = \lambda_n - \tau^{-1}(\nabla g(x_n + \tau v\lambda_n) v)^{-1} g(x_n + \tau v \lambda_n)
# $$

# %% [markdown]
# ### First, load neceesary packages

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import torch
import math 
import torch.nn as nn
import random
import itertools 
from tqdm import tqdm
import os
import time

# %% [markdown]
# ### Optimizer

# %%
def newton_projection(g, model, X, v_direction, tau, res_tol=1e-3, max_newton_steps=100):       
    iter_step = 0
    converged = False
    projection_iter_steps = 0 
            
    while iter_step < max_newton_steps:
        g_now = g(model, X)
        
        if iter_step == 0:
            k = len(g_now)
            lam = np.zeros((k))
       # if self.verbose:
        print (f'projection step={iter_step}, g={g_now.detach().item():.3e}')
            
        if torch.linalg.norm(g_now) < res_tol:
            converged = True
            break

        grad_g = [torch.autograd.grad(g_now[idx], model.parameters(), 
                                      create_graph=True, retain_graph=True, allow_unused=True) for idx in range(k)]
               
        with torch.no_grad():
            mat = np.zeros((k, k))
            for i in range(k):
                for j in range(k):
                    for z1, z2 in zip(grad_g[i], v_direction[j]):
                        if z1 is not None: # and z2 is not None:
                            mat[i,j] += (z1 * z2).sum()
                            
            dlam = -1.0 * np.linalg.solve(mat, g_now.numpy()) / tau
            lam += dlam
            for i in range(k):
                for param, z2 in zip(model.parameters(), v_direction[i]):
                    if z2 is not None:
                        param.add_(z2 * dlam[i] * tau)
                    
        iter_step += 1
    
    return converged, iter_step, lam 
        
class ProjectedSGD():
    
    def __init__(self, model, f, g, beta=1.0, tau=1e-1, res_tol=1e-3, max_newton_steps=100, verbose=True):
        self.f = f
        self.g = g
        self.tau = tau
        self.res_tol = res_tol
        self.max_newton_steps = max_newton_steps
        self.verbose = verbose
        self.model = model
        self.beta = beta
        self.X = None
        
    def reset_data(self, X):
        self.X = X
        
    def unconstrained_update(self):
        self.loss = self.f(self.model, self.X)
        self._grad_f = torch.autograd.grad(self.loss, self.model.parameters(), allow_unused=True)

        with torch.no_grad():
            for param, grad in zip(self.model.parameters(), self._grad_f):
                rn = torch.normal(torch.zeros(param.size()), torch.ones(param.size()))
                if grad is not None:
                    param.add_(-1.0 * grad * self.tau + math.sqrt(2.0 * self.tau / self.beta) * rn)       
                else :
                    param.add_(math.sqrt(2.0 * self.tau / self.beta) * rn)       
                    
    def projection_update(self):
        g_val = self.g(self.model, self.X)
        grad_g_prev = [torch.autograd.grad(g_val[idx], self.model.parameters(), 
                                      create_graph=True, retain_graph=True, allow_unused=True) for idx in range(len(g_val))] 
        
        self.converged, self.projection_iter_steps, lam = newton_projection(self.g, self.model, self.X,
                                                                            grad_g_prev, self.tau, 
                                                                            self.res_tol, self.max_newton_steps)
        
    def is_succeed(self):
        return self.converged
    
    def projection_steps(self):
        return self.projection_iter_steps

    def step(self, X):
        self.reset_data(X)
        self.unconstrained_update()
        self.projection_update()
        
class ProjectedLangevin():
    def __init__(self, model, f, g, tau=0.1, beta=1.0, alpha=0.5, res_tol=1e-5, max_newton_steps=100):
        self.model = model
        self.tau = tau
        self.beta = beta
        self.alpha = alpha
        self.res_tol = res_tol
        self.max_newton_steps = max_newton_steps
        self.p_list = []
        self.g = g
        self.f = f
        self.X = None
        for param in model.parameters():
            self.p_list.append(torch.zeros(param.size()))
    
    def reset_data(self, X):
        self.X = X
               
    def unconstrained_update(self):
        self.loss = self.f(self.model, self.X)
        # momnentum update
        grad_f = torch.autograd.grad(self.loss, self.model.parameters(), allow_unused=True)
        
        with torch.no_grad():
            for param, grad in zip (self.p_list, grad_f):
                param.add_(-0.5 * self.tau * grad)

            # position update
            for param, param_p in zip (self.model.parameters(), self.p_list):
                #print (param_p)
                param.add_(self.tau * param_p)
    
    def projection_momentum(self):
        g_val = self.g(self.model, self.X)
        k = len(g_val)
        grad_g = [torch.autograd.grad(g_val[idx], self.model.parameters(), 
                                      create_graph=True, retain_graph=True, allow_unused=True) for idx in range(k)]
        with torch.no_grad():
            mat = np.zeros((k, k))
            for i in range(k):
                for j in range(k):
                    for z1, z2 in zip(grad_g[i], grad_g[j]):
                        mat[i,j] += (z1 * z2).sum()            
                        
            lam = np.zeros((k))
            for idx in range(k):
                for param, grad in zip (self.p_list, grad_g[idx]):        
                    lam[idx] += (param * grad).sum()
                    
            coeff = np.linalg.solve(mat, lam)    
                    
            for idx in range(k):
                for param, grad in zip (self.p_list, grad_g[idx]):        
                    param.add_(-1.0 * coeff[idx] * grad)
                                                    
    def momentum_refresh(self):
        for param in self.p_list:
            rn = torch.normal(torch.zeros(param.size()), torch.ones(param.size()))
            param.add_((self.alpha - 1.0) * param + math.sqrt((1-self.alpha**2)/self.beta) * rn)
        self.projection_momentum()
            
    def projection(self):
        g_val = self.g(self.model, self.X)
        k = len(g_val)
        grad_g_prev = [torch.autograd.grad(g_val[idx], self.model.parameters(), 
                                      create_graph=True, retain_graph=True, allow_unused=True) for idx in range(k)] 
        
        #project position, x -> x_{1}
        converged, iter_steps, lam = newton_projection(self.g, self.model, self.X, grad_g_prev, self.tau, 
                                                       self.res_tol, self.max_newton_steps)
        
        self.loss = self.f(self.model, self.X)
        # momnentum update: p_{1/2}->p_1
        grad_f = torch.autograd.grad(self.loss, self.model.parameters(), allow_unused=True)               
                
        with torch.no_grad():
            # modify momentum to get p_{1/2}
            for idx in range(k):
                for param, grad in zip (self.p_list, grad_g_prev[idx]):
                    param.add_(grad * lam[idx])

            # momnentum update: p_{1/2}->p_1
            for param, grad in zip (self.p_list, grad_f):
                param.add_(-0.5 * self.tau * grad)
        
        self.projection_momentum()
        
        # p_1 -> p_{1,-}
        for param in self.p_list:
            param *= -1.0

    def step(self, X):
        self.reset_data(X)
        self.momentum_refresh()
        self.unconstrained_update()
        self.projection()
#        self.momentum_refresh()

# %%
class func_g:
    def __init__(self, X, y=1):
        self.k = 1
        self.y = y
        self.X = X
    def __call__(self, model):
        Z = model(self.X)
        tmp = ((Z**2).sum()-self.y).reshape((1))
        return tmp
    
class Simple(torch.nn.Module):
    def __init__(self):
        super(Simple, self).__init__()
        self.x = torch.nn.Parameter(torch.tensor([3.0, 1.0]))
    def forward(self, X):
        return X.sum()
    
def simple_f(model, X=None):
    return model.x[0] + model.x[1]

def simple_g(model, X=None):
    return 0.5 * (model.x[0]**2 + model.x[1]**2 - 1.0).reshape((1))

# %%
class SimpleBad(torch.nn.Module):
    def __init__(self):
        super(SimpleBad, self).__init__()
        self.x = torch.nn.Parameter(torch.tensor([1., 1.0, 0.1]))
    def forward(self, X):
        return X.sum()
    
def simple_g_bad(model, X=None):
    return 0.5* ((model.x[1]+model.x[2])**2 + (model.x[0]+model.x[2])**2 - 1.0).reshape((1))
#    return 0.5 * ((model.x[1]+model.x[2])**2 + (model.x[0]+model.x[2]-1.0)**2).reshape((1))

model = SimpleBad()

g_val = simple_g_bad(model, None)
grad_g_prev = [torch.autograd.grad(g_val[idx], model.parameters(), 
                                      create_graph=True, retain_graph=True, allow_unused=True) for idx in range(len(g_val))] 
        
newton_projection(simple_g_bad, model, None, grad_g_prev, tau=0.1)
# Out:
# projection step=0, g=7.100e-01
# projection step=1, g=1.042e-01
# projection step=2, g=4.489e-03
# projection step=3, g=9.954e-06
# (True, 3, array([-1.19056413]))

# %% [markdown]
# ### Test 1

# %%
model = Simple()
opt = ProjectedSGD(model, simple_f, simple_g, tau=0.01, beta=20.0, verbose=True)
#opt = ProjectedLangevin(model, simple_f, simple_g, tau=0.3, beta=8.0, alpha=0.5)

n_steps = 1000
for idx in range(n_steps):
    opt.step(None)
    if idx % 100 == 0:
        print (f'step={idx}, loss={opt.loss.detach().numpy()}')
    #print (model.x.detach().numpy())
print (model.x.detach().numpy())
# Out:
# projection step=0, g=4.260e+00
# projection step=1, g=9.531e-01
# projection step=2, g=1.563e-01
# projection step=3, g=9.305e-03
# projection step=4, g=4.250e-05
# step=0, loss=4.0
# projection step=0, g=-2.196e-02
# projection step=1, g=2.521e-04
# projection step=0, g=-1.208e-02
# projection step=1, g=7.468e-05
# projection step=0, g=7.020e-02
# projection step=1, g=2.161e-03
# projection step=2, g=2.325e-06
# projection step=0, g=2.696e-02
# projection step=1, g=3.449e-04
# projection step=0, g=-3.545e-02
# projection step=1, g=6.762e-04
# projection step=0, g=-3.201e-02
# projection step=1, g=5.473e-04
# projection step=0, g=-1.680e-02
# projection step=1, g=1.460e-04
# projection step=0, g=-3.042e-02
# projection step=1, g=4.928e-04
# projection step=0, g=-5.456e-02
# projection step=1, g=1.671e-03
# projection step=2, g=1.431e-06
# projection step=0, g=-4.501e-03
# projection step=1, g=1.025e-05
# projection step=0, g=-2.022e-02
# projection step=1, g=2.130e-04
# projection step=0, g=5.796e-02
# projection step=1, g=1.505e-03
# projection step=2, g=1.073e-06
# projection step=0, g=-5.132e-02
# projection step=1, g=1.468e-03
# projection step=2, g=1.073e-06
# projection step=0, g=-1.254e-02
# projection step=1, g=8.059e-05
# projection step=0, g=1.797e-03
# projection step=1, g=1.669e-06
# projection step=0, g=-6.571e-02
# projection step=1, g=2.485e-03
# projection step=2, g=3.099e-06
# projection step=0, g=-3.548e-02
# projection step=1, g=6.777e-04
# projection step=0, g=-9.441e-03
# projection step=1, g=4.548e-05
# projection step=0, g=-4.166e-02
# projection step=1, g=9.468e-04
# projection step=0, g=2.401e-03
# projection step=1, g=2.861e-06
# projection step=0, g=4.674e-03
# projection step=1, g=1.091e-05
# projection step=0, g=6.821e-02
# projection step=1, g=2.047e-03
# projection step=2, g=2.086e-06
# projection step=0, g=-2.728e-03
# projection step=1, g=3.695e-06
# projection step=0, g=3.914e-02
# projection step=1, g=7.104e-04
# projection step=0, g=-4.139e-02
# projection step=1, g=9.338e-04
# projection step=0, g=-2.737e-03
# projection step=1, g=3.755e-06
# projection step=0, g=4.067e-02
# projection step=1, g=7.648e-04
# projection step=0, g=1.711e-02
# projection step=1, g=1.415e-04
# projection step=0, g=-2.473e-02
# projection step=1, g=3.217e-04
# projection step=0, g=-2.018e-02
# projection step=1, g=2.121e-04
# projection step=0, g=1.594e-02
# projection step=1, g=1.231e-04
# projection step=0, g=1.619e-02
# projection step=1, g=1.271e-04
# projection step=0, g=-4.509e-02
# projection step=1, g=1.117e-03
# projection step=2, g=6.557e-07
# projection step=0, g=-1.659e-02
# projection step=1, g=1.423e-04
# projection step=0, g=-1.353e-02
# projection step=1, g=9.412e-05
# projection step=0, g=-4.169e-02
# projection step=1, g=9.479e-04
# projection step=0, g=-5.291e-02
# projection step=1, g=1.565e-03
# projection step=2, g=1.192e-06
# projection step=0, g=-2.904e-03
# projection step=1, g=4.292e-06
# projection step=0, g=1.422e-02
# projection step=1, g=9.823e-05
# projection step=0, g=-3.883e-02
# projection step=1, g=8.173e-04
# projection step=0, g=3.336e-02
# projection step=1, g=5.218e-04
# projection step=0, g=-5.231e-04
# projection step=0, g=9.498e-03
# projection step=1, g=4.429e-05
# projection step=0, g=-1.021e-02
# projection step=1, g=5.323e-05
# projection step=0, g=2.446e-02
# projection step=1, g=2.853e-04
# projection step=0, g=-1.355e-02
# projection step=1, g=9.429e-05
# projection step=0, g=-1.870e-02
# projection step=1, g=1.816e-04
# projection step=0, g=-2.751e-02
# projection step=1, g=4.004e-04
# projection step=0, g=4.873e-02
# projection step=1, g=1.082e-03
# projection step=2, g=5.364e-07
# projection step=0, g=-7.376e-02
# projection step=1, g=3.191e-03
# projection step=2, g=5.007e-06
# projection step=0, g=4.926e-02
# projection step=1, g=1.104e-03
# projection step=2, g=5.960e-07
# projection step=0, g=-6.087e-02
# projection step=1, g=2.109e-03
# projection step=2, g=2.205e-06
# projection step=0, g=-2.347e-02
# projection step=1, g=2.891e-04
# projection step=0, g=1.861e-02
# projection step=1, g=1.670e-04
# projection step=0, g=2.787e-02
# projection step=1, g=3.678e-04
# projection step=0, g=-1.156e-02
# projection step=1, g=6.849e-05
# projection step=0, g=1.944e-02
# projection step=1, g=1.819e-04
# projection step=0, g=-1.030e-02
# projection step=1, g=5.412e-05
# projection step=0, g=-7.050e-03
# projection step=1, g=2.521e-05
# projection step=0, g=4.069e-02
# projection step=1, g=7.653e-04
# projection step=0, g=5.124e-03
# projection step=1, g=1.305e-05
# projection step=0, g=-9.268e-03
# projection step=1, g=4.375e-05
# projection step=0, g=-3.686e-02
# projection step=1, g=7.332e-04
# projection step=0, g=9.988e-03
# projection step=1, g=4.894e-05
# projection step=0, g=-1.981e-02
# projection step=1, g=2.043e-04
# projection step=0, g=-2.423e-03
# projection step=1, g=2.980e-06
# projection step=0, g=6.968e-03
# projection step=1, g=2.396e-05
# projection step=0, g=3.697e-02
# projection step=1, g=6.363e-04
# projection step=0, g=-5.904e-03
# projection step=1, g=1.764e-05
# projection step=0, g=1.790e-02
# projection step=1, g=1.547e-04
# projection step=0, g=-3.976e-02
# projection step=1, g=8.588e-04
# projection step=0, g=6.306e-02
# projection step=1, g=1.766e-03
# projection step=2, g=1.550e-06
# projection step=0, g=-6.821e-02
# projection step=1, g=2.694e-03
# projection step=2, g=3.636e-06
# projection step=0, g=-5.756e-02
# projection step=1, g=1.872e-03
# projection step=2, g=1.729e-06
# projection step=0, g=4.113e-02
# projection step=1, g=7.814e-04
# projection step=0, g=-1.637e-03
# projection step=1, g=1.311e-06
# projection step=0, g=5.817e-02
# projection step=1, g=1.515e-03
# projection step=2, g=1.073e-06
# projection step=0, g=-9.999e-04
# projection step=0, g=-4.035e-02
# projection step=1, g=8.854e-04
# projection step=0, g=2.292e-03
# projection step=1, g=2.623e-06
# projection step=0, g=-1.743e-02
# projection step=1, g=1.575e-04
# projection step=0, g=3.365e-02
# projection step=1, g=5.304e-04
# projection step=0, g=1.135e-02
# projection step=1, g=6.300e-05
# projection step=0, g=-3.006e-02
# projection step=1, g=4.807e-04
# projection step=0, g=-3.830e-02
# projection step=1, g=7.941e-04
# projection step=0, g=3.125e-02
# projection step=1, g=4.594e-04
# projection step=0, g=9.781e-03
# projection step=1, g=4.685e-05
# projection step=0, g=7.631e-02
# projection step=1, g=2.526e-03
# projection step=2, g=3.159e-06
# projection step=0, g=-2.604e-02
# projection step=1, g=3.576e-04
# projection step=0, g=5.349e-02
# projection step=1, g=1.292e-03
# projection step=2, g=8.345e-07
# projection step=0, g=-3.275e-02
# projection step=1, g=5.738e-04
# projection step=0, g=-6.424e-03
# projection step=1, g=2.092e-05
# projection step=0, g=2.314e-02
# projection step=1, g=2.558e-04
# projection step=0, g=1.614e-02
# projection step=1, g=1.262e-04
# projection step=0, g=-2.238e-02
# projection step=1, g=2.621e-04
# projection step=0, g=2.701e-02
# projection step=1, g=3.460e-04
# projection step=0, g=2.216e-02
# projection step=1, g=2.351e-04
# projection step=0, g=1.431e-04
# projection step=0, g=-6.981e-03
# projection step=1, g=2.468e-05
# projection step=0, g=1.473e-02
# projection step=1, g=1.053e-04
# step=100, loss=-0.7828367352485657
# projection step=0, g=-1.539e-02
# projection step=1, g=1.222e-04
# projection step=0, g=-2.219e-02
# projection step=1, g=2.577e-04
# projection step=0, g=1.836e-03
# projection step=1, g=1.669e-06
# projection step=0, g=2.465e-02
# projection step=1, g=2.896e-04
# projection step=0, g=-5.254e-03
# projection step=1, g=1.395e-05
# projection step=0, g=1.720e-02
# projection step=1, g=1.429e-04
# projection step=0, g=5.967e-02
# projection step=1, g=1.590e-03
# projection step=2, g=1.252e-06
# projection step=0, g=3.542e-02
# projection step=1, g=5.859e-04
# projection step=0, g=6.411e-02
# projection step=1, g=1.821e-03
# projection step=2, g=1.669e-06
# projection step=0, g=2.817e-02
# projection step=1, g=3.756e-04
# projection step=0, g=-1.034e-02
# projection step=1, g=5.454e-05
# projection step=0, g=4.779e-02
# projection step=1, g=1.042e-03
# projection step=2, g=5.364e-07
# projection step=0, g=-2.120e-02
# projection step=1, g=2.347e-04
# projection step=0, g=-2.930e-02
# projection step=1, g=4.559e-04
# projection step=0, g=-4.435e-02
# projection step=1, g=1.079e-03
# projection step=2, g=5.960e-07
# projection step=0, g=-1.829e-02
# projection step=1, g=1.737e-04
# projection step=0, g=9.232e-02
# projection step=1, g=3.598e-03
# projection step=2, g=6.437e-06
# projection step=0, g=-3.650e-04
# projection step=0, g=3.552e-02
# projection step=1, g=5.890e-04
# projection step=0, g=2.140e-03
# projection step=1, g=2.265e-06
# projection step=0, g=2.254e-02
# projection step=1, g=2.431e-04
# projection step=0, g=5.270e-02
# projection step=1, g=1.256e-03
# projection step=2, g=7.749e-07
# projection step=0, g=-2.335e-02
# projection step=1, g=2.859e-04
# projection step=0, g=-2.369e-02
# projection step=1, g=2.946e-04
# projection step=0, g=1.857e-02
# projection step=1, g=1.662e-04
# projection step=0, g=-6.202e-02
# projection step=1, g=2.195e-03
# projection step=2, g=2.384e-06
# projection step=0, g=-3.137e-03
# projection step=1, g=4.947e-06
# projection step=0, g=4.170e-02
# projection step=1, g=8.023e-04
# projection step=0, g=-1.752e-02
# projection step=1, g=1.590e-04
# projection step=0, g=3.599e-02
# projection step=1, g=6.042e-04
# projection step=0, g=9.647e-03
# projection step=1, g=4.566e-05
# projection step=0, g=-1.043e-02
# projection step=1, g=5.561e-05
# projection step=0, g=4.203e-03
# projection step=1, g=8.702e-06
# projection step=0, g=6.711e-02
# projection step=1, g=1.985e-03
# projection step=2, g=1.967e-06
# projection step=0, g=-5.382e-02
# projection step=1, g=1.623e-03
# projection step=2, g=1.371e-06
# projection step=0, g=3.024e-02
# projection step=1, g=4.311e-04
# projection step=0, g=7.534e-03
# projection step=1, g=2.789e-05
# projection step=0, g=2.017e-03
# projection step=1, g=2.027e-06
# projection step=0, g=1.348e-02
# projection step=1, g=8.851e-05
# projection step=0, g=8.531e-03
# projection step=1, g=3.582e-05
# projection step=0, g=-2.730e-02
# projection step=1, g=3.942e-04
# projection step=0, g=2.378e-02
# projection step=1, g=2.699e-04
# projection step=0, g=9.107e-03
# projection step=1, g=4.071e-05
# projection step=0, g=2.906e-02
# projection step=1, g=3.990e-04
# projection step=0, g=6.577e-02
# projection step=1, g=1.912e-03
# projection step=2, g=1.788e-06
# projection step=0, g=3.584e-02
# projection step=1, g=5.994e-04
# projection step=0, g=1.747e-02
# projection step=1, g=1.476e-04
# projection step=0, g=3.454e-02
# projection step=1, g=5.581e-04
# projection step=0, g=4.500e-02
# projection step=1, g=9.290e-04
# projection step=0, g=-3.486e-02
# projection step=1, g=6.531e-04
# projection step=0, g=-2.954e-02
# projection step=1, g=4.638e-04
# projection step=0, g=2.688e-02
# projection step=1, g=3.428e-04
# projection step=0, g=1.243e-02
# projection step=1, g=7.534e-05
# projection step=0, g=-2.209e-02
# projection step=1, g=2.552e-04
# projection step=0, g=-5.187e-03
# projection step=1, g=1.359e-05
# projection step=0, g=2.964e-02
# projection step=1, g=4.146e-04
# projection step=0, g=4.186e-02
# projection step=1, g=8.086e-04
# projection step=0, g=5.179e-03
# projection step=1, g=1.335e-05
# projection step=0, g=2.216e-02
# projection step=1, g=2.351e-04
# projection step=0, g=-4.441e-02
# projection step=1, g=1.082e-03
# projection step=2, g=5.364e-07
# projection step=0, g=3.258e-02
# projection step=1, g=4.983e-04
# projection step=0, g=4.531e-04
# projection step=0, g=1.347e-02
# projection step=1, g=8.833e-05
# projection step=0, g=5.761e-02
# projection step=1, g=1.488e-03
# projection step=2, g=1.132e-06
# projection step=0, g=2.789e-02
# projection step=1, g=3.682e-04
# projection step=0, g=-3.042e-02
# projection step=1, g=4.927e-04
# projection step=0, g=9.547e-03
# projection step=1, g=4.470e-05
# projection step=0, g=7.619e-03
# projection step=1, g=2.861e-05
# projection step=0, g=-2.232e-02
# projection step=1, g=2.607e-04
# projection step=0, g=-6.089e-03
# projection step=1, g=1.872e-05
# projection step=0, g=-1.357e-02
# projection step=1, g=9.465e-05
# projection step=0, g=6.879e-02
# projection step=1, g=2.080e-03
# projection step=2, g=2.146e-06
# projection step=0, g=6.716e-02
# projection step=1, g=1.988e-03
# projection step=2, g=1.967e-06
# projection step=0, g=3.299e-02
# projection step=1, g=5.105e-04
# projection step=0, g=-2.471e-02
# projection step=1, g=3.211e-04
# projection step=0, g=3.883e-02
# projection step=1, g=6.995e-04
# projection step=0, g=3.162e-02
# projection step=1, g=4.702e-04
# projection step=0, g=1.502e-02
# projection step=1, g=1.094e-04
# projection step=0, g=3.867e-02
# projection step=1, g=6.940e-04
# projection step=0, g=-6.824e-03
# projection step=1, g=2.360e-05
# projection step=0, g=-5.161e-02
# projection step=1, g=1.485e-03
# projection step=2, g=1.132e-06
# projection step=0, g=1.201e-02
# projection step=1, g=7.039e-05
# projection step=0, g=-3.673e-03
# projection step=1, g=6.855e-06
# projection step=0, g=6.165e-02
# projection step=1, g=1.692e-03
# projection step=2, g=1.431e-06
# projection step=0, g=7.086e-02
# projection step=1, g=2.199e-03
# projection step=2, g=2.444e-06
# projection step=0, g=2.562e-02
# projection step=1, g=3.123e-04
# projection step=0, g=3.658e-02
# projection step=1, g=6.236e-04
# projection step=0, g=7.644e-02
# projection step=1, g=2.534e-03
# projection step=2, g=3.159e-06
# projection step=0, g=5.932e-04
# projection step=0, g=3.754e-02
# projection step=1, g=6.554e-04
# projection step=0, g=3.314e-03
# projection step=1, g=5.424e-06
# projection step=0, g=4.293e-02
# projection step=1, g=8.488e-04
# projection step=0, g=7.242e-04
# projection step=0, g=2.001e-02
# projection step=1, g=1.926e-04
# projection step=0, g=3.996e-02
# projection step=1, g=7.393e-04
# projection step=0, g=-3.455e-02
# projection step=1, g=6.411e-04
# projection step=0, g=3.833e-02
# projection step=1, g=6.823e-04
# projection step=0, g=4.734e-02
# projection step=1, g=1.023e-03
# projection step=2, g=5.364e-07
# projection step=0, g=7.372e-02
# projection step=1, g=2.368e-03
# projection step=2, g=2.742e-06
# projection step=0, g=1.812e-03
# projection step=1, g=1.609e-06
# step=200, loss=-1.4108928442001343
# projection step=0, g=1.745e-02
# projection step=1, g=1.470e-04
# projection step=0, g=6.926e-02
# projection step=1, g=2.107e-03
# projection step=2, g=2.265e-06
# projection step=0, g=5.224e-03
# projection step=1, g=1.359e-05
# projection step=0, g=9.716e-03
# projection step=1, g=4.625e-05
# projection step=0, g=1.635e-02
# projection step=1, g=1.294e-04
# projection step=0, g=-4.463e-03
# projection step=1, g=1.001e-05
# projection step=0, g=-2.827e-03
# projection step=1, g=4.053e-06
# projection step=0, g=2.279e-03
# projection step=1, g=2.623e-06
# projection step=0, g=3.204e-03
# projection step=1, g=5.126e-06
# projection step=0, g=4.919e-02
# projection step=1, g=1.101e-03
# projection step=2, g=5.960e-07
# projection step=0, g=6.225e-02
# projection step=1, g=1.723e-03
# projection step=2, g=1.431e-06
# projection step=0, g=-1.164e-02
# projection step=1, g=6.932e-05
# projection step=0, g=3.677e-02
# projection step=1, g=6.296e-04
# projection step=0, g=3.382e-02
# projection step=1, g=5.356e-04
# projection step=0, g=-1.018e-02
# projection step=1, g=5.293e-05
# projection step=0, g=3.927e-03
# projection step=1, g=7.629e-06
# projection step=0, g=1.060e-02
# projection step=1, g=5.496e-05
# projection step=0, g=3.698e-02
# projection step=1, g=6.366e-04
# projection step=0, g=4.529e-02
# projection step=1, g=9.405e-04
# projection step=0, g=5.829e-02
# projection step=1, g=1.522e-03
# projection step=2, g=1.192e-06
# projection step=0, g=-2.061e-02
# projection step=1, g=2.215e-04
# projection step=0, g=1.896e-02
# projection step=1, g=1.733e-04
# projection step=0, g=2.004e-02
# projection step=1, g=1.931e-04
# projection step=0, g=-1.980e-02
# projection step=1, g=2.041e-04
# projection step=0, g=-3.233e-02
# projection step=1, g=5.586e-04
# projection step=0, g=1.640e-02
# projection step=1, g=1.302e-04
# projection step=0, g=-2.921e-02
# projection step=1, g=4.532e-04
# projection step=0, g=-2.839e-02
# projection step=1, g=4.272e-04
# projection step=0, g=2.909e-02
# projection step=1, g=3.999e-04
# projection step=0, g=4.417e-02
# projection step=1, g=8.963e-04
# projection step=0, g=1.514e-02
# projection step=1, g=1.113e-04
# projection step=0, g=5.860e-02
# projection step=1, g=1.537e-03
# projection step=2, g=1.192e-06
# projection step=0, g=1.877e-02
# projection step=1, g=1.698e-04
# projection step=0, g=4.595e-02
# projection step=1, g=9.666e-04
# projection step=0, g=1.895e-03
# projection step=1, g=1.788e-06
# projection step=0, g=6.789e-02
# projection step=1, g=2.029e-03
# projection step=2, g=2.086e-06
# projection step=0, g=-2.242e-02
# projection step=1, g=2.630e-04
# projection step=0, g=6.045e-04
# projection step=0, g=4.811e-02
# projection step=1, g=1.056e-03
# projection step=2, g=5.364e-07
# projection step=0, g=-1.387e-02
# projection step=1, g=9.894e-05
# projection step=0, g=1.674e-02
# projection step=1, g=1.357e-04
# projection step=0, g=6.893e-02
# projection step=1, g=2.088e-03
# projection step=2, g=2.205e-06
# projection step=0, g=-4.375e-02
# projection step=1, g=1.049e-03
# projection step=2, g=5.960e-07
# projection step=0, g=3.086e-02
# projection step=1, g=4.485e-04
# projection step=0, g=5.939e-03
# projection step=1, g=1.740e-05
# projection step=0, g=2.651e-02
# projection step=1, g=3.339e-04
# projection step=0, g=2.374e-02
# projection step=1, g=2.689e-04
# projection step=0, g=-4.018e-02
# projection step=1, g=8.778e-04
# projection step=0, g=-6.022e-02
# projection step=1, g=2.061e-03
# projection step=2, g=2.146e-06
# projection step=0, g=-1.043e-02
# projection step=1, g=5.555e-05
# projection step=0, g=1.101e-01
# projection step=1, g=4.968e-03
# projection step=2, g=1.228e-05
# projection step=0, g=1.360e-02
# projection step=1, g=9.000e-05
# projection step=0, g=1.197e-02
# projection step=1, g=6.998e-05
# projection step=0, g=5.886e-02
# projection step=1, g=1.550e-03
# projection step=2, g=1.192e-06
# projection step=0, g=5.859e-02
# projection step=1, g=1.536e-03
# projection step=2, g=1.192e-06
# projection step=0, g=1.148e-02
# projection step=1, g=6.449e-05
# projection step=0, g=-6.970e-02
# projection step=1, g=2.822e-03
# projection step=2, g=3.934e-06
# projection step=0, g=7.663e-02
# projection step=1, g=2.546e-03
# projection step=2, g=3.219e-06
# projection step=0, g=2.039e-02
# projection step=1, g=1.997e-04
# projection step=0, g=2.429e-02
# projection step=1, g=2.813e-04
# projection step=0, g=-5.811e-02
# projection step=1, g=1.910e-03
# projection step=2, g=1.848e-06
# projection step=0, g=-1.067e-02
# projection step=1, g=5.823e-05
# projection step=0, g=-1.255e-02
# projection step=1, g=8.082e-05
# projection step=0, g=3.630e-02
# projection step=1, g=6.142e-04
# projection step=0, g=-2.840e-02
# projection step=1, g=4.277e-04
# projection step=0, g=-2.928e-02
# projection step=1, g=4.553e-04
# projection step=0, g=3.354e-02
# projection step=1, g=5.271e-04
# projection step=0, g=-2.577e-02
# projection step=1, g=3.499e-04
# projection step=0, g=1.145e-01
# projection step=1, g=5.333e-03
# projection step=2, g=1.407e-05
# projection step=0, g=5.383e-02
# projection step=1, g=1.308e-03
# projection step=2, g=8.345e-07
# projection step=0, g=4.160e-02
# projection step=1, g=7.987e-04
# projection step=0, g=5.431e-02
# projection step=1, g=1.330e-03
# projection step=2, g=9.537e-07
# projection step=0, g=9.701e-03
# projection step=1, g=4.613e-05
# projection step=0, g=2.958e-03
# projection step=1, g=4.351e-06
# projection step=0, g=-1.059e-02
# projection step=1, g=5.728e-05
# projection step=0, g=5.172e-04
# projection step=0, g=5.736e-02
# projection step=1, g=1.476e-03
# projection step=2, g=1.073e-06
# projection step=0, g=2.773e-02
# projection step=1, g=3.642e-04
# projection step=0, g=3.432e-02
# projection step=1, g=5.510e-04
# projection step=0, g=-3.404e-02
# projection step=1, g=6.216e-04
# projection step=0, g=4.306e-02
# projection step=1, g=8.537e-04
# projection step=0, g=-2.336e-02
# projection step=1, g=2.862e-04
# projection step=0, g=9.773e-03
# projection step=1, g=4.685e-05
# projection step=0, g=-3.474e-02
# projection step=1, g=6.486e-04
# projection step=0, g=1.449e-02
# projection step=1, g=1.020e-04
# projection step=0, g=4.941e-03
# projection step=1, g=1.210e-05
# projection step=0, g=1.034e-02
# projection step=1, g=5.233e-05
# projection step=0, g=2.094e-02
# projection step=1, g=2.104e-04
# projection step=0, g=3.184e-02
# projection step=1, g=4.765e-04
# projection step=0, g=6.460e-02
# projection step=1, g=1.848e-03
# projection step=2, g=1.669e-06
# projection step=0, g=3.039e-03
# projection step=1, g=4.530e-06
# projection step=0, g=-7.885e-03
# projection step=1, g=3.153e-05
# projection step=0, g=2.322e-03
# projection step=1, g=2.742e-06
# projection step=0, g=1.118e-02
# projection step=1, g=6.109e-05
# projection step=0, g=6.752e-03
# projection step=1, g=2.253e-05
# projection step=0, g=-1.752e-02
# projection step=1, g=1.590e-04
# projection step=0, g=1.409e-02
# projection step=1, g=9.656e-05
# projection step=0, g=3.298e-02
# projection step=1, g=5.103e-04
# projection step=0, g=7.953e-02
# projection step=1, g=2.729e-03
# projection step=2, g=3.695e-06
# projection step=0, g=-5.830e-03
# projection step=1, g=1.723e-05
# step=300, loss=-1.4141860008239746
# projection step=0, g=-4.900e-03
# projection step=1, g=1.216e-05
# projection step=0, g=3.291e-02
# projection step=1, g=5.081e-04
# projection step=0, g=1.649e-03
# projection step=1, g=1.311e-06
# projection step=0, g=-1.338e-02
# projection step=1, g=9.191e-05
# projection step=0, g=3.995e-02
# projection step=1, g=7.389e-04
# projection step=0, g=4.422e-02
# projection step=1, g=8.984e-04
# projection step=0, g=3.334e-02
# projection step=1, g=5.209e-04
# projection step=0, g=3.333e-03
# projection step=1, g=5.543e-06
# projection step=0, g=2.045e-02
# projection step=1, g=2.009e-04
# projection step=0, g=1.293e-02
# projection step=1, g=8.142e-05
# projection step=0, g=-1.449e-03
# projection step=1, g=1.073e-06
# projection step=0, g=-3.602e-02
# projection step=1, g=6.991e-04
# projection step=0, g=8.396e-02
# projection step=1, g=3.018e-03
# projection step=2, g=4.530e-06
# projection step=0, g=1.066e-02
# projection step=1, g=5.567e-05
# projection step=0, g=3.017e-02
# projection step=1, g=4.293e-04
# projection step=0, g=-1.801e-02
# projection step=1, g=1.682e-04
# projection step=0, g=2.560e-02
# projection step=1, g=3.119e-04
# projection step=0, g=5.064e-02
# projection step=1, g=1.164e-03
# projection step=2, g=6.557e-07
# projection step=0, g=-1.389e-02
# projection step=1, g=9.930e-05
# projection step=0, g=5.746e-02
# projection step=1, g=1.481e-03
# projection step=2, g=1.073e-06
# projection step=0, g=-4.491e-02
# projection step=1, g=1.108e-03
# projection step=2, g=5.960e-07
# projection step=0, g=1.124e-03
# projection step=1, g=5.960e-07
# projection step=0, g=4.504e-02
# projection step=1, g=9.305e-04
# projection step=0, g=4.460e-02
# projection step=1, g=9.131e-04
# projection step=0, g=4.869e-02
# projection step=1, g=1.080e-03
# projection step=2, g=5.960e-07
# projection step=0, g=5.325e-03
# projection step=1, g=1.407e-05
# projection step=0, g=1.934e-04
# projection step=0, g=4.281e-02
# projection step=1, g=8.439e-04
# projection step=0, g=1.172e-02
# projection step=1, g=6.717e-05
# projection step=0, g=5.304e-02
# projection step=1, g=1.272e-03
# projection step=2, g=8.345e-07
# projection step=0, g=7.240e-03
# projection step=1, g=2.587e-05
# projection step=0, g=-3.179e-02
# projection step=1, g=5.395e-04
# projection step=0, g=6.828e-03
# projection step=1, g=2.295e-05
# projection step=0, g=2.180e-02
# projection step=1, g=2.277e-04
# projection step=0, g=6.392e-02
# projection step=1, g=1.811e-03
# projection step=2, g=1.609e-06
# projection step=0, g=1.826e-02
# projection step=1, g=1.609e-04
# projection step=0, g=-4.273e-02
# projection step=1, g=9.980e-04
# projection step=0, g=1.112e-02
# projection step=1, g=6.044e-05
# projection step=0, g=1.002e-02
# projection step=1, g=4.923e-05
# projection step=0, g=2.237e-03
# projection step=1, g=2.503e-06
# projection step=0, g=4.733e-02
# projection step=1, g=1.023e-03
# projection step=2, g=5.364e-07
# projection step=0, g=-5.493e-03
# projection step=1, g=1.520e-05
# projection step=0, g=4.450e-02
# projection step=1, g=9.090e-04
# projection step=0, g=7.592e-02
# projection step=1, g=2.502e-03
# projection step=2, g=3.159e-06
# projection step=0, g=2.125e-03
# projection step=1, g=2.265e-06
# projection step=0, g=7.805e-02
# projection step=1, g=2.635e-03
# projection step=2, g=3.457e-06
# projection step=0, g=-2.885e-02
# projection step=1, g=4.418e-04
# projection step=0, g=-1.231e-02
# projection step=1, g=7.772e-05
# projection step=0, g=-3.760e-02
# projection step=1, g=7.645e-04
# projection step=0, g=-1.593e-02
# projection step=1, g=1.311e-04
# projection step=0, g=-5.075e-03
# projection step=1, g=1.299e-05
# projection step=0, g=6.181e-02
# projection step=1, g=1.700e-03
# projection step=2, g=1.431e-06
# projection step=0, g=-4.371e-02
# projection step=1, g=1.047e-03
# projection step=2, g=5.960e-07
# projection step=0, g=1.464e-03
# projection step=1, g=1.073e-06
# projection step=0, g=4.151e-02
# projection step=1, g=7.956e-04
# projection step=0, g=-8.886e-03
# projection step=1, g=4.017e-05
# projection step=0, g=2.446e-02
# projection step=1, g=2.853e-04
# projection step=0, g=2.745e-02
# projection step=1, g=3.572e-04
# projection step=0, g=1.077e-02
# projection step=1, g=5.686e-05
# projection step=0, g=2.182e-02
# projection step=1, g=2.280e-04
# projection step=0, g=7.364e-03
# projection step=1, g=2.670e-05
# projection step=0, g=6.844e-02
# projection step=1, g=2.060e-03
# projection step=2, g=2.086e-06
# projection step=0, g=2.037e-02
# projection step=1, g=1.993e-04
# projection step=0, g=5.386e-02
# projection step=1, g=1.309e-03
# projection step=2, g=8.941e-07
# projection step=0, g=3.189e-02
# projection step=1, g=4.780e-04
# projection step=0, g=3.219e-02
# projection step=1, g=4.867e-04
# projection step=0, g=-5.327e-02
# projection step=1, g=1.588e-03
# projection step=2, g=1.252e-06
# projection step=0, g=-2.479e-02
# projection step=1, g=3.233e-04
# projection step=0, g=4.350e-02
# projection step=1, g=8.703e-04
# projection step=0, g=1.454e-02
# projection step=1, g=1.026e-04
# projection step=0, g=-1.561e-02
# projection step=1, g=1.257e-04
# projection step=0, g=4.271e-03
# projection step=1, g=9.000e-06
# projection step=0, g=-9.436e-03
# projection step=1, g=4.542e-05
# projection step=0, g=1.330e-02
# projection step=1, g=8.619e-05
# projection step=0, g=-1.539e-02
# projection step=1, g=1.223e-04
# projection step=0, g=6.037e-02
# projection step=1, g=1.626e-03
# projection step=2, g=1.311e-06
# projection step=0, g=3.411e-02
# projection step=1, g=5.445e-04
# projection step=0, g=-2.703e-03
# projection step=1, g=3.636e-06
# projection step=0, g=3.208e-02
# projection step=1, g=4.834e-04
# projection step=0, g=8.431e-02
# projection step=1, g=3.041e-03
# projection step=2, g=4.649e-06
# projection step=0, g=5.249e-02
# projection step=1, g=1.247e-03
# projection step=2, g=7.749e-07
# projection step=0, g=1.748e-02
# projection step=1, g=1.475e-04
# projection step=0, g=1.201e-02
# projection step=1, g=7.045e-05
# projection step=0, g=2.037e-02
# projection step=1, g=1.992e-04
# projection step=0, g=-2.064e-03
# projection step=1, g=2.146e-06
# projection step=0, g=4.559e-02
# projection step=1, g=9.522e-04
# projection step=0, g=3.605e-02
# projection step=1, g=6.061e-04
# projection step=0, g=2.956e-03
# projection step=1, g=4.351e-06
# projection step=0, g=8.768e-03
# projection step=1, g=3.779e-05
# projection step=0, g=3.094e-02
# projection step=1, g=4.507e-04
# projection step=0, g=4.763e-02
# projection step=1, g=1.036e-03
# projection step=2, g=5.364e-07
# projection step=0, g=3.742e-02
# projection step=1, g=6.514e-04
# projection step=0, g=1.359e-02
# projection step=1, g=8.988e-05
# projection step=0, g=-2.150e-02
# projection step=1, g=2.415e-04
# projection step=0, g=-4.061e-03
# projection step=1, g=8.285e-06
# projection step=0, g=5.140e-03
# projection step=1, g=1.311e-05
# projection step=0, g=3.989e-02
# projection step=1, g=7.369e-04
# projection step=0, g=5.239e-02
# projection step=1, g=1.242e-03
# projection step=2, g=7.749e-07
# projection step=0, g=-1.775e-02
# projection step=1, g=1.633e-04
# projection step=0, g=-3.292e-02
# projection step=1, g=5.799e-04
# step=400, loss=-1.3923227787017822
# projection step=0, g=2.921e-06
# projection step=0, g=2.185e-02
# projection step=1, g=2.287e-04
# projection step=0, g=-3.018e-02
# projection step=1, g=4.846e-04
# projection step=0, g=3.736e-02
# projection step=1, g=6.493e-04
# projection step=0, g=3.582e-02
# projection step=1, g=5.988e-04
# projection step=0, g=2.656e-02
# projection step=1, g=3.350e-04
# projection step=0, g=1.103e-03
# projection step=1, g=6.557e-07
# projection step=0, g=-4.376e-02
# projection step=1, g=1.049e-03
# projection step=2, g=4.768e-07
# projection step=0, g=4.311e-02
# projection step=1, g=8.555e-04
# projection step=0, g=2.162e-02
# projection step=1, g=2.241e-04
# projection step=0, g=1.077e-02
# projection step=1, g=5.674e-05
# projection step=0, g=1.852e-02
# projection step=1, g=1.653e-04
# projection step=0, g=2.784e-02
# projection step=1, g=3.672e-04
# projection step=0, g=4.014e-02
# projection step=1, g=7.457e-04
# projection step=0, g=-2.614e-02
# projection step=1, g=3.604e-04
# projection step=0, g=3.721e-02
# projection step=1, g=6.444e-04
# projection step=0, g=1.663e-02
# projection step=1, g=1.338e-04
# projection step=0, g=1.005e-01
# projection step=1, g=4.203e-03
# projection step=2, g=8.762e-06
# projection step=0, g=1.184e-02
# projection step=1, g=6.849e-05
# projection step=0, g=7.033e-06
# projection step=0, g=2.497e-02
# projection step=1, g=2.970e-04
# projection step=0, g=-4.428e-03
# projection step=1, g=9.894e-06
# projection step=0, g=-3.638e-02
# projection step=1, g=7.136e-04
# projection step=0, g=2.841e-02
# projection step=1, g=3.818e-04
# projection step=0, g=2.237e-02
# projection step=1, g=2.396e-04
# projection step=0, g=6.146e-02
# projection step=1, g=1.682e-03
# projection step=2, g=1.431e-06
# projection step=0, g=2.403e-02
# projection step=1, g=2.754e-04
# projection step=0, g=-3.231e-03
# projection step=1, g=5.245e-06
# projection step=0, g=5.797e-02
# projection step=1, g=1.506e-03
# projection step=2, g=1.132e-06
# projection step=0, g=2.367e-02
# projection step=1, g=2.674e-04
# projection step=0, g=4.964e-02
# projection step=1, g=1.121e-03
# projection step=2, g=6.557e-07
# projection step=0, g=5.258e-02
# projection step=1, g=1.251e-03
# projection step=2, g=7.749e-07
# projection step=0, g=5.179e-02
# projection step=1, g=1.215e-03
# projection step=2, g=7.153e-07
# projection step=0, g=2.702e-02
# projection step=1, g=3.463e-04
# projection step=0, g=5.095e-02
# projection step=1, g=1.178e-03
# projection step=2, g=7.153e-07
# projection step=0, g=3.927e-02
# projection step=1, g=7.148e-04
# projection step=0, g=2.997e-02
# projection step=1, g=4.237e-04
# projection step=0, g=-6.991e-03
# projection step=1, g=2.480e-05
# projection step=0, g=-2.542e-02
# projection step=1, g=3.405e-04
# projection step=0, g=1.303e-02
# projection step=1, g=8.273e-05
# projection step=0, g=-8.478e-02
# projection step=1, g=4.328e-03
# projection step=2, g=9.298e-06
# projection step=0, g=1.572e-03
# projection step=1, g=1.252e-06
# projection step=0, g=5.335e-02
# projection step=1, g=1.286e-03
# projection step=2, g=8.345e-07
# projection step=0, g=2.583e-03
# projection step=1, g=3.338e-06
# projection step=0, g=1.020e-02
# projection step=1, g=5.096e-05
# projection step=0, g=1.793e-02
# projection step=1, g=1.552e-04
# projection step=0, g=-2.360e-02
# projection step=1, g=2.924e-04
# projection step=0, g=1.662e-02
# projection step=1, g=1.338e-04
# projection step=0, g=9.138e-02
# projection step=1, g=3.530e-03
# projection step=2, g=6.199e-06
# projection step=0, g=1.487e-02
# projection step=1, g=1.072e-04
# projection step=0, g=6.623e-02
# projection step=1, g=1.937e-03
# projection step=2, g=1.788e-06
# projection step=0, g=-5.377e-03
# projection step=1, g=1.460e-05
# projection step=0, g=6.621e-02
# projection step=1, g=1.935e-03
# projection step=2, g=1.848e-06
# projection step=0, g=-2.427e-02
# projection step=1, g=3.096e-04
# projection step=0, g=4.013e-02
# projection step=1, g=7.455e-04
# projection step=0, g=-1.976e-05
# projection step=0, g=8.841e-03
# projection step=1, g=3.833e-05
# projection step=0, g=4.673e-02
# projection step=1, g=9.986e-04
# projection step=0, g=6.349e-02
# projection step=1, g=1.788e-03
# projection step=2, g=1.609e-06
# projection step=0, g=4.973e-02
# projection step=1, g=1.125e-03
# projection step=2, g=5.960e-07
# projection step=0, g=-6.464e-03
# projection step=1, g=2.116e-05
# projection step=0, g=6.794e-02
# projection step=1, g=2.032e-03
# projection step=2, g=2.027e-06
# projection step=0, g=-6.632e-02
# projection step=1, g=2.536e-03
# projection step=2, g=3.219e-06
# projection step=0, g=-4.820e-02
# projection step=1, g=1.285e-03
# projection step=2, g=8.345e-07
# projection step=0, g=3.104e-02
# projection step=1, g=4.536e-04
# projection step=0, g=2.546e-03
# projection step=1, g=3.219e-06
# projection step=0, g=-3.663e-02
# projection step=1, g=7.240e-04
# projection step=0, g=4.675e-02
# projection step=1, g=9.993e-04
# projection step=0, g=4.966e-02
# projection step=1, g=1.121e-03
# projection step=2, g=5.960e-07
# projection step=0, g=1.772e-02
# projection step=1, g=1.515e-04
# projection step=0, g=3.091e-03
# projection step=1, g=4.709e-06
# projection step=0, g=3.540e-02
# projection step=1, g=5.852e-04
# projection step=0, g=1.222e-02
# projection step=1, g=7.284e-05
# projection step=0, g=1.391e-02
# projection step=1, g=9.406e-05
# projection step=0, g=3.183e-02
# projection step=1, g=4.762e-04
# projection step=0, g=4.390e-02
# projection step=1, g=8.858e-04
# projection step=0, g=2.924e-02
# projection step=1, g=4.038e-04
# projection step=0, g=5.732e-02
# projection step=1, g=1.474e-03
# projection step=2, g=1.073e-06
# projection step=0, g=4.174e-03
# projection step=1, g=8.583e-06
# projection step=0, g=6.181e-02
# projection step=1, g=1.700e-03
# projection step=2, g=1.431e-06
# projection step=0, g=-4.203e-02
# projection step=1, g=9.645e-04
# projection step=0, g=-2.603e-02
# projection step=1, g=3.575e-04
# projection step=0, g=7.517e-02
# projection step=1, g=2.456e-03
# projection step=2, g=3.040e-06
# projection step=0, g=7.072e-02
# projection step=1, g=2.191e-03
# projection step=2, g=2.384e-06
# projection step=0, g=3.861e-02
# projection step=1, g=6.918e-04
# projection step=0, g=2.077e-02
# projection step=1, g=2.071e-04
# projection step=0, g=-1.814e-02
# projection step=1, g=1.706e-04
# projection step=0, g=9.107e-03
# projection step=1, g=4.077e-05
# projection step=0, g=3.619e-02
# projection step=1, g=6.108e-04
# projection step=0, g=2.752e-02
# projection step=1, g=3.588e-04
# projection step=0, g=1.939e-02
# projection step=1, g=1.810e-04
# projection step=0, g=-1.264e-02
# projection step=1, g=8.190e-05
# projection step=0, g=-3.950e-02
# projection step=1, g=8.470e-04
# projection step=0, g=4.785e-02
# projection step=1, g=1.045e-03
# projection step=2, g=5.364e-07
# projection step=0, g=-2.886e-02
# projection step=1, g=4.419e-04
# projection step=0, g=-5.122e-02
# projection step=1, g=1.461e-03
# projection step=2, g=1.073e-06
# projection step=0, g=-1.378e-02
# projection step=1, g=9.757e-05
# projection step=0, g=4.095e-03
# projection step=1, g=8.285e-06
# projection step=0, g=2.520e-02
# projection step=1, g=3.022e-04
# projection step=0, g=-2.486e-02
# projection step=1, g=3.253e-04
# step=500, loss=-1.414550542831421
# projection step=0, g=2.492e-02
# projection step=1, g=2.958e-04
# projection step=0, g=-7.476e-03
# projection step=1, g=2.837e-05
# projection step=0, g=-1.086e-02
# projection step=1, g=6.026e-05
# projection step=0, g=3.368e-02
# projection step=1, g=5.313e-04
# projection step=0, g=3.175e-02
# projection step=1, g=4.740e-04
# projection step=0, g=-1.708e-02
# projection step=1, g=1.509e-04
# projection step=0, g=9.964e-03
# projection step=1, g=4.870e-05
# projection step=0, g=2.352e-02
# projection step=1, g=2.643e-04
# projection step=0, g=2.245e-02
# projection step=1, g=2.412e-04
# projection step=0, g=3.077e-02
# projection step=1, g=4.461e-04
# projection step=0, g=3.787e-02
# projection step=1, g=6.665e-04
# projection step=0, g=8.254e-02
# projection step=1, g=2.924e-03
# projection step=2, g=4.232e-06
# projection step=0, g=4.790e-02
# projection step=1, g=1.047e-03
# projection step=2, g=5.960e-07
# projection step=0, g=-2.742e-02
# projection step=1, g=3.976e-04
# projection step=0, g=1.034e-02
# projection step=1, g=5.233e-05
# projection step=0, g=4.823e-02
# projection step=1, g=1.061e-03
# projection step=2, g=5.364e-07
# projection step=0, g=2.032e-02
# projection step=1, g=1.983e-04
# projection step=0, g=1.324e-02
# projection step=1, g=8.535e-05
# projection step=0, g=-1.424e-02
# projection step=1, g=1.044e-04
# projection step=0, g=-1.789e-03
# projection step=1, g=1.550e-06
# projection step=0, g=4.092e-02
# projection step=1, g=7.739e-04
# projection step=0, g=1.080e-01
# projection step=1, g=4.794e-03
# projection step=2, g=1.144e-05
# projection step=0, g=-4.299e-02
# projection step=1, g=1.011e-03
# projection step=2, g=4.768e-07
# projection step=0, g=4.128e-03
# projection step=1, g=8.404e-06
# projection step=0, g=4.417e-02
# projection step=1, g=8.963e-04
# projection step=0, g=-2.282e-02
# projection step=1, g=2.728e-04
# projection step=0, g=3.155e-02
# projection step=1, g=4.681e-04
# projection step=0, g=1.942e-02
# projection step=1, g=1.816e-04
# projection step=0, g=-2.534e-02
# projection step=1, g=3.383e-04
# projection step=0, g=-2.616e-02
# projection step=1, g=3.611e-04
# projection step=0, g=1.690e-03
# projection step=1, g=1.431e-06
# projection step=0, g=4.114e-03
# projection step=1, g=8.464e-06
# projection step=0, g=1.848e-02
# projection step=1, g=1.646e-04
# projection step=0, g=-3.019e-02
# projection step=1, g=4.851e-04
# projection step=0, g=1.720e-02
# projection step=1, g=1.429e-04
# projection step=0, g=-1.329e-02
# projection step=1, g=9.072e-05
# projection step=0, g=1.831e-02
# projection step=1, g=1.616e-04
# projection step=0, g=9.667e-02
# projection step=1, g=3.916e-03
# projection step=2, g=7.629e-06
# projection step=0, g=6.095e-02
# projection step=1, g=1.656e-03
# projection step=2, g=1.311e-06
# projection step=0, g=4.933e-02
# projection step=1, g=1.108e-03
# projection step=2, g=6.557e-07
# projection step=0, g=5.760e-02
# projection step=1, g=1.487e-03
# projection step=2, g=1.073e-06
# projection step=0, g=-2.505e-03
# projection step=1, g=3.159e-06
# projection step=0, g=2.577e-02
# projection step=1, g=3.158e-04
# projection step=0, g=-8.407e-03
# projection step=1, g=3.600e-05
# projection step=0, g=3.343e-02
# projection step=1, g=5.238e-04
# projection step=0, g=-3.962e-03
# projection step=1, g=7.927e-06
# projection step=0, g=3.643e-02
# projection step=1, g=6.183e-04
# projection step=0, g=3.042e-02
# projection step=1, g=4.361e-04
# projection step=0, g=-1.774e-02
# projection step=1, g=1.632e-04
# projection step=0, g=1.656e-02
# projection step=1, g=1.327e-04
# projection step=0, g=-1.679e-02
# projection step=1, g=1.459e-04
# projection step=0, g=2.959e-02
# projection step=1, g=4.134e-04
# projection step=0, g=9.065e-04
# projection step=0, g=6.781e-02
# projection step=1, g=2.024e-03
# projection step=2, g=2.027e-06
# projection step=0, g=-3.707e-02
# projection step=1, g=7.423e-04
# projection step=0, g=6.242e-04
# projection step=0, g=3.917e-02
# projection step=1, g=7.115e-04
# projection step=0, g=-1.235e-02
# projection step=1, g=7.820e-05
# projection step=0, g=1.463e-02
# projection step=1, g=1.040e-04
# projection step=0, g=2.867e-02
# projection step=1, g=3.886e-04
# projection step=0, g=2.909e-03
# projection step=1, g=4.292e-06
# projection step=0, g=9.731e-02
# projection step=1, g=3.963e-03
# projection step=2, g=7.749e-06
# projection step=0, g=-6.984e-03
# projection step=1, g=2.474e-05
# projection step=0, g=-5.009e-04
# projection step=0, g=4.249e-03
# projection step=1, g=8.941e-06
# projection step=0, g=1.372e-02
# projection step=1, g=9.155e-05
# projection step=0, g=-3.395e-02
# projection step=1, g=6.182e-04
# projection step=0, g=5.450e-02
# projection step=1, g=1.339e-03
# projection step=2, g=9.537e-07
# projection step=0, g=6.068e-02
# projection step=1, g=1.642e-03
# projection step=2, g=1.311e-06
# projection step=0, g=-3.371e-02
# projection step=1, g=6.092e-04
# projection step=0, g=3.501e-02
# projection step=1, g=5.726e-04
# projection step=0, g=-2.857e-02
# projection step=1, g=4.330e-04
# projection step=0, g=3.728e-02
# projection step=1, g=6.465e-04
# projection step=0, g=2.105e-02
# projection step=1, g=2.126e-04
# projection step=0, g=-5.295e-03
# projection step=1, g=1.419e-05
# projection step=0, g=9.108e-02
# projection step=1, g=3.508e-03
# projection step=2, g=6.080e-06
# projection step=0, g=-2.904e-02
# projection step=1, g=4.476e-04
# projection step=0, g=6.564e-03
# projection step=1, g=2.128e-05
# projection step=0, g=5.013e-02
# projection step=1, g=1.142e-03
# projection step=2, g=6.557e-07
# projection step=0, g=2.444e-02
# projection step=1, g=2.847e-04
# projection step=0, g=1.171e-02
# projection step=1, g=6.706e-05
# projection step=0, g=7.372e-03
# projection step=1, g=2.676e-05
# projection step=0, g=6.682e-02
# projection step=1, g=1.969e-03
# projection step=2, g=1.907e-06
# projection step=0, g=-2.359e-03
# projection step=1, g=2.801e-06
# projection step=0, g=6.947e-03
# projection step=1, g=2.378e-05
# projection step=0, g=2.084e-02
# projection step=1, g=2.085e-04
# projection step=0, g=-2.273e-02
# projection step=1, g=2.705e-04
# projection step=0, g=-1.026e-02
# projection step=1, g=5.376e-05
# projection step=0, g=-7.098e-03
# projection step=1, g=2.551e-05
# projection step=0, g=-9.909e-03
# projection step=1, g=5.007e-05
# projection step=0, g=2.342e-02
# projection step=1, g=2.620e-04
# projection step=0, g=3.989e-02
# projection step=1, g=7.368e-04
# projection step=0, g=-3.140e-02
# projection step=1, g=5.261e-04
# projection step=0, g=7.116e-03
# projection step=1, g=2.497e-05
# projection step=0, g=-5.287e-02
# projection step=1, g=1.563e-03
# projection step=2, g=1.252e-06
# projection step=0, g=3.751e-02
# projection step=1, g=6.545e-04
# projection step=0, g=1.722e-02
# projection step=1, g=1.433e-04
# projection step=0, g=-1.099e-02
# projection step=1, g=6.169e-05
# projection step=0, g=-1.369e-02
# projection step=1, g=9.638e-05
# projection step=0, g=4.688e-02
# projection step=1, g=1.005e-03
# projection step=2, g=5.364e-07
# step=600, loss=-1.4074327945709229
# projection step=0, g=1.159e-02
# projection step=1, g=6.562e-05
# projection step=0, g=-4.764e-02
# projection step=1, g=1.254e-03
# projection step=2, g=7.749e-07
# projection step=0, g=-3.784e-02
# projection step=1, g=7.746e-04
# projection step=0, g=7.542e-02
# projection step=1, g=2.472e-03
# projection step=2, g=3.099e-06
# projection step=0, g=-2.910e-02
# projection step=1, g=4.495e-04
# projection step=0, g=5.302e-03
# projection step=1, g=1.389e-05
# projection step=0, g=1.376e-02
# projection step=1, g=9.215e-05
# projection step=0, g=1.899e-02
# projection step=1, g=1.738e-04
# projection step=0, g=-1.196e-02
# projection step=1, g=7.319e-05
# projection step=0, g=8.641e-03
# projection step=1, g=3.672e-05
# projection step=0, g=2.373e-03
# projection step=1, g=2.801e-06
# projection step=0, g=1.897e-02
# projection step=1, g=1.733e-04
# projection step=0, g=3.627e-02
# projection step=1, g=6.133e-04
# projection step=0, g=6.075e-02
# projection step=1, g=1.645e-03
# projection step=2, g=1.371e-06
# projection step=0, g=7.129e-03
# projection step=1, g=2.509e-05
# projection step=0, g=1.579e-02
# projection step=1, g=1.208e-04
# projection step=0, g=-1.866e-02
# projection step=1, g=1.808e-04
# projection step=0, g=-2.034e-02
# projection step=1, g=2.156e-04
# projection step=0, g=2.401e-02
# projection step=1, g=2.749e-04
# projection step=0, g=-1.399e-02
# projection step=1, g=1.006e-04
# projection step=0, g=4.228e-04
# projection step=0, g=5.086e-03
# projection step=1, g=1.281e-05
# projection step=0, g=-1.829e-02
# projection step=1, g=1.737e-04
# projection step=0, g=-4.935e-02
# projection step=1, g=1.351e-03
# projection step=2, g=8.941e-07
# projection step=0, g=-1.045e-02
# projection step=1, g=5.579e-05
# projection step=0, g=9.812e-03
# projection step=1, g=4.721e-05
# projection step=0, g=3.102e-02
# projection step=1, g=4.530e-04
# projection step=0, g=2.265e-02
# projection step=1, g=2.453e-04
# projection step=0, g=-8.839e-03
# projection step=1, g=3.976e-05
# projection step=0, g=5.603e-02
# projection step=1, g=1.411e-03
# projection step=2, g=1.013e-06
# projection step=0, g=2.798e-02
# projection step=1, g=3.706e-04
# projection step=0, g=-2.341e-02
# projection step=1, g=2.874e-04
# projection step=0, g=-2.052e-02
# projection step=1, g=2.195e-04
# projection step=0, g=-2.464e-02
# projection step=1, g=3.193e-04
# projection step=0, g=1.468e-03
# projection step=1, g=1.073e-06
# projection step=0, g=2.943e-03
# projection step=1, g=4.292e-06
# projection step=0, g=4.129e-02
# projection step=1, g=7.875e-04
# projection step=0, g=4.234e-02
# projection step=1, g=8.265e-04
# projection step=0, g=8.170e-03
# projection step=1, g=3.284e-05
# projection step=0, g=-1.093e-02
# projection step=1, g=6.104e-05
# projection step=0, g=-1.602e-02
# projection step=1, g=1.326e-04
# projection step=0, g=3.324e-02
# projection step=1, g=5.181e-04
# projection step=0, g=2.121e-02
# projection step=1, g=2.158e-04
# projection step=0, g=5.898e-02
# projection step=1, g=1.556e-03
# projection step=2, g=1.192e-06
# projection step=0, g=-2.121e-02
# projection step=1, g=2.348e-04
# projection step=0, g=4.925e-02
# projection step=1, g=1.104e-03
# projection step=2, g=5.960e-07
# projection step=0, g=-8.543e-03
# projection step=1, g=3.713e-05
# projection step=0, g=1.857e-02
# projection step=1, g=1.662e-04
# projection step=0, g=2.931e-02
# projection step=1, g=4.057e-04
# projection step=0, g=1.002e-01
# projection step=1, g=4.184e-03
# projection step=2, g=8.643e-06
# projection step=0, g=4.058e-03
# projection step=1, g=8.106e-06
# projection step=0, g=-4.289e-03
# projection step=1, g=9.298e-06
# projection step=0, g=3.285e-02
# projection step=1, g=5.065e-04
# projection step=0, g=6.163e-03
# projection step=1, g=1.872e-05
# projection step=0, g=3.528e-02
# projection step=1, g=5.813e-04
# projection step=0, g=-1.608e-02
# projection step=1, g=1.336e-04
# projection step=0, g=-1.378e-03
# projection step=1, g=9.537e-07
# projection step=0, g=5.983e-02
# projection step=1, g=1.599e-03
# projection step=2, g=1.252e-06
# projection step=0, g=2.792e-02
# projection step=1, g=3.691e-04
# projection step=0, g=2.296e-02
# projection step=1, g=2.521e-04
# projection step=0, g=-3.138e-02
# projection step=1, g=5.253e-04
# projection step=0, g=1.175e-02
# projection step=1, g=6.741e-05
# projection step=0, g=9.935e-04
# projection step=0, g=-2.965e-02
# projection step=1, g=4.671e-04
# projection step=0, g=-2.255e-02
# projection step=1, g=2.662e-04
# projection step=0, g=1.092e-02
# projection step=1, g=5.829e-05
# projection step=0, g=-8.900e-03
# projection step=1, g=4.035e-05
# projection step=0, g=1.234e-02
# projection step=1, g=7.433e-05
# projection step=0, g=4.222e-02
# projection step=1, g=8.220e-04
# projection step=0, g=-5.965e-03
# projection step=1, g=1.800e-05
# projection step=0, g=1.220e-02
# projection step=1, g=7.266e-05
# projection step=0, g=-1.902e-02
# projection step=1, g=1.880e-04
# projection step=0, g=3.519e-02
# projection step=1, g=5.783e-04
# projection step=0, g=-1.919e-02
# projection step=1, g=1.915e-04
# projection step=0, g=-9.113e-03
# projection step=1, g=4.226e-05
# projection step=0, g=-3.549e-02
# projection step=1, g=6.779e-04
# projection step=0, g=1.506e-02
# projection step=1, g=1.100e-04
# projection step=0, g=1.341e-02
# projection step=1, g=8.762e-05
# projection step=0, g=3.281e-02
# projection step=1, g=5.051e-04
# projection step=0, g=7.740e-03
# projection step=1, g=2.950e-05
# projection step=0, g=-3.396e-03
# projection step=1, g=5.782e-06
# projection step=0, g=6.028e-03
# projection step=1, g=1.794e-05
# projection step=0, g=-2.636e-02
# projection step=1, g=3.669e-04
# projection step=0, g=1.288e-02
# projection step=1, g=8.088e-05
# projection step=0, g=8.401e-04
# projection step=0, g=3.240e-02
# projection step=1, g=4.929e-04
# projection step=0, g=-4.364e-02
# projection step=1, g=1.043e-03
# projection step=2, g=5.364e-07
# projection step=0, g=1.390e-02
# projection step=1, g=9.400e-05
# projection step=0, g=2.282e-02
# projection step=1, g=2.490e-04
# projection step=0, g=3.070e-02
# projection step=1, g=4.441e-04
# projection step=0, g=-1.983e-02
# projection step=1, g=2.047e-04
# projection step=0, g=9.153e-02
# projection step=1, g=3.541e-03
# projection step=2, g=6.199e-06
# projection step=0, g=1.902e-02
# projection step=1, g=1.744e-04
# projection step=0, g=-4.769e-02
# projection step=1, g=1.257e-03
# projection step=2, g=7.749e-07
# projection step=0, g=1.887e-02
# projection step=1, g=1.716e-04
# projection step=0, g=2.377e-02
# projection step=1, g=2.698e-04
# projection step=0, g=-6.984e-03
# projection step=1, g=2.468e-05
# projection step=0, g=2.190e-02
# projection step=1, g=2.298e-04
# projection step=0, g=3.896e-02
# projection step=1, g=7.039e-04
# projection step=0, g=4.230e-03
# projection step=1, g=8.881e-06
# step=700, loss=-1.3980586528778076
# projection step=0, g=9.610e-02
# projection step=1, g=3.873e-03
# projection step=2, g=7.451e-06
# projection step=0, g=7.887e-03
# projection step=1, g=3.058e-05
# projection step=0, g=-1.079e-02
# projection step=1, g=5.943e-05
# projection step=0, g=1.477e-02
# projection step=1, g=1.060e-04
# projection step=0, g=5.877e-02
# projection step=1, g=1.545e-03
# ...
# projection step=1, g=2.955e-04
# projection step=0, g=6.281e-02
# projection step=1, g=1.752e-03
# projection step=2, g=1.490e-06
# projection step=0, g=2.102e-02
# projection step=1, g=2.120e-04
# projection step=0, g=2.379e-03
# projection step=1, g=2.742e-06
# projection step=0, g=9.171e-02
# projection step=1, g=3.554e-03
# projection step=2, g=6.258e-06
# projection step=0, g=3.878e-02
# projection step=1, g=6.979e-04
# projection step=0, g=-4.224e-03
# projection step=1, g=9.000e-06
# projection step=0, g=-4.416e-03
# projection step=1, g=9.835e-06
# projection step=0, g=-1.449e-02
# projection step=1, g=1.081e-04
# projection step=0, g=1.123e-02
# projection step=1, g=6.175e-05
# projection step=0, g=6.649e-02
# projection step=1, g=1.951e-03
# projection step=2, g=1.907e-06
# projection step=0, g=3.164e-02
# projection step=1, g=4.708e-04
# projection step=0, g=9.542e-03
# projection step=1, g=4.470e-05
# projection step=0, g=1.666e-02
# projection step=1, g=1.342e-04
# projection step=0, g=4.341e-02
# projection step=1, g=8.670e-04
# projection step=0, g=8.625e-02
# projection step=1, g=3.172e-03
# projection step=2, g=4.947e-06
# projection step=0, g=-1.171e-02
# projection step=1, g=7.015e-05
# projection step=0, g=1.066e-02
# projection step=1, g=5.567e-05
# projection step=0, g=-7.834e-03
# projection step=1, g=3.123e-05
# projection step=0, g=1.376e-02
# projection step=1, g=9.209e-05
# projection step=0, g=6.637e-02
# projection step=1, g=1.944e-03
# projection step=2, g=1.907e-06
# projection step=0, g=1.080e-02
# projection step=1, g=5.710e-05
# projection step=0, g=-1.708e-02
# projection step=1, g=1.510e-04
# projection step=0, g=1.987e-02
# projection step=1, g=1.898e-04
# projection step=0, g=2.310e-02
# projection step=1, g=2.550e-04
# projection step=0, g=3.419e-03
# projection step=1, g=5.782e-06
# projection step=0, g=4.900e-02
# projection step=1, g=1.093e-03
# projection step=2, g=5.960e-07
# projection step=0, g=5.804e-02
# projection step=1, g=1.509e-03
# projection step=2, g=1.073e-06
# projection step=0, g=-4.093e-03
# projection step=1, g=8.464e-06
# projection step=0, g=1.495e-02
# projection step=1, g=1.085e-04
# projection step=0, g=5.079e-02
# projection step=1, g=1.171e-03
# projection step=2, g=6.557e-07
# projection step=0, g=-1.432e-02
# projection step=1, g=1.055e-04
# projection step=0, g=-3.232e-02
# projection step=1, g=5.585e-04
# projection step=0, g=4.856e-02
# projection step=1, g=1.075e-03
# projection step=2, g=5.364e-07
# projection step=0, g=3.704e-02
# projection step=1, g=6.388e-04
# projection step=0, g=5.178e-02
# projection step=1, g=1.215e-03
# projection step=2, g=7.153e-07
# step=800, loss=-1.408191442489624
# projection step=0, g=-3.290e-02
# projection step=1, g=5.793e-04
# projection step=0, g=2.363e-02
# projection step=1, g=2.666e-04
# projection step=0, g=2.631e-02
# projection step=1, g=3.287e-04
# projection step=0, g=3.544e-02
# projection step=1, g=5.866e-04
# projection step=0, g=-3.718e-03
# projection step=1, g=6.974e-06
# projection step=0, g=2.058e-02
# projection step=1, g=2.033e-04
# projection step=0, g=-6.457e-02
# projection step=1, g=2.394e-03
# projection step=2, g=2.742e-06
# projection step=0, g=2.440e-02
# projection step=1, g=2.839e-04
# projection step=0, g=8.431e-02
# projection step=1, g=3.041e-03
# projection step=2, g=4.530e-06
# projection step=0, g=3.649e-02
# projection step=1, g=6.204e-04
# projection step=0, g=-1.858e-02
# projection step=1, g=1.792e-04
# projection step=0, g=4.147e-03
# projection step=1, g=8.523e-06
# projection step=0, g=-9.186e-04
# projection step=0, g=8.330e-02
# projection step=1, g=2.974e-03
# projection step=2, g=4.351e-06
# projection step=0, g=7.083e-02
# projection step=1, g=2.197e-03
# projection step=2, g=2.384e-06
# projection step=0, g=6.579e-03
# projection step=1, g=2.134e-05
# projection step=0, g=3.705e-02
# projection step=1, g=6.390e-04
# projection step=0, g=2.470e-02
# projection step=1, g=2.908e-04
# projection step=0, g=6.714e-02
# projection step=1, g=1.987e-03
# projection step=2, g=1.967e-06
# projection step=0, g=-7.728e-03
# projection step=1, g=3.034e-05
# projection step=0, g=3.067e-02
# projection step=1, g=4.432e-04
# projection step=0, g=-2.402e-02
# projection step=1, g=3.029e-04
# projection step=0, g=1.238e-02
# projection step=1, g=7.480e-05
# projection step=0, g=2.095e-02
# projection step=1, g=2.106e-04
# projection step=0, g=5.139e-03
# projection step=1, g=1.299e-05
# projection step=0, g=-1.939e-02
# projection step=1, g=1.956e-04
# projection step=0, g=1.982e-02
# projection step=1, g=1.889e-04
# projection step=0, g=3.378e-02
# projection step=1, g=5.345e-04
# projection step=0, g=3.487e-02
# projection step=1, g=5.682e-04
# projection step=0, g=-3.612e-02
# projection step=1, g=7.030e-04
# projection step=0, g=9.621e-03
# projection step=1, g=4.542e-05
# projection step=0, g=2.065e-02
# projection step=1, g=2.047e-04
# projection step=0, g=6.218e-02
# projection step=1, g=1.719e-03
# projection step=2, g=1.490e-06
# projection step=0, g=1.257e-02
# projection step=1, g=7.701e-05
# projection step=0, g=4.139e-02
# projection step=1, g=7.910e-04
# projection step=0, g=-1.073e-02
# projection step=1, g=5.877e-05
# projection step=0, g=8.765e-03
# projection step=1, g=3.779e-05
# projection step=0, g=-7.989e-03
# projection step=1, g=3.242e-05
# projection step=0, g=7.689e-02
# projection step=1, g=2.562e-03
# projection step=2, g=3.278e-06
# projection step=0, g=1.332e-02
# projection step=1, g=8.643e-05
# projection step=0, g=-6.955e-03
# projection step=1, g=2.450e-05
# projection step=0, g=-1.837e-02
# projection step=1, g=1.752e-04
# projection step=0, g=2.418e-02
# projection step=1, g=2.789e-04
# projection step=0, g=2.240e-02
# projection step=1, g=2.400e-04
# projection step=0, g=3.087e-02
# projection step=1, g=4.487e-04
# projection step=0, g=2.750e-02
# projection step=1, g=3.583e-04
# projection step=0, g=2.044e-02
# projection step=1, g=2.007e-04
# projection step=0, g=-3.422e-02
# projection step=1, g=6.285e-04
# projection step=0, g=1.432e-02
# projection step=1, g=9.966e-05
# projection step=0, g=5.227e-03
# projection step=1, g=1.353e-05
# projection step=0, g=5.192e-02
# projection step=1, g=1.221e-03
# projection step=2, g=7.749e-07
# projection step=0, g=3.201e-02
# projection step=1, g=4.814e-04
# projection step=0, g=7.072e-03
# projection step=1, g=2.468e-05
# projection step=0, g=-4.174e-02
# projection step=1, g=9.503e-04
# projection step=0, g=2.264e-03
# projection step=1, g=2.563e-06
# projection step=0, g=6.152e-02
# projection step=1, g=1.685e-03
# projection step=2, g=1.431e-06
# projection step=0, g=-2.211e-02
# projection step=1, g=2.556e-04
# projection step=0, g=1.787e-02
# projection step=1, g=1.541e-04
# projection step=0, g=4.473e-02
# projection step=1, g=9.183e-04
# projection step=0, g=2.696e-02
# projection step=1, g=3.448e-04
# projection step=0, g=-3.139e-02
# projection step=1, g=5.257e-04
# projection step=0, g=3.325e-02
# projection step=1, g=5.182e-04
# projection step=0, g=9.816e-04
# projection step=0, g=-1.067e-02
# projection step=1, g=5.811e-05
# projection step=0, g=-5.820e-02
# projection step=1, g=1.917e-03
# projection step=2, g=1.788e-06
# projection step=0, g=6.605e-02
# projection step=1, g=1.927e-03
# projection step=2, g=1.848e-06
# projection step=0, g=1.904e-02
# projection step=1, g=1.747e-04
# projection step=0, g=1.130e-02
# projection step=1, g=6.235e-05
# projection step=0, g=-5.601e-03
# projection step=1, g=1.585e-05
# projection step=0, g=-4.751e-02
# projection step=1, g=1.247e-03
# projection step=2, g=8.345e-07
# projection step=0, g=-3.601e-02
# projection step=1, g=6.986e-04
# projection step=0, g=3.869e-03
# projection step=1, g=7.451e-06
# projection step=0, g=5.550e-02
# projection step=1, g=1.386e-03
# projection step=2, g=9.537e-07
# projection step=0, g=-2.138e-02
# projection step=1, g=2.387e-04
# projection step=0, g=4.314e-03
# projection step=1, g=9.239e-06
# projection step=0, g=9.370e-03
# projection step=1, g=4.309e-05
# projection step=0, g=1.458e-02
# projection step=1, g=1.032e-04
# projection step=0, g=2.445e-03
# projection step=1, g=2.980e-06
# projection step=0, g=-3.431e-04
# projection step=0, g=-1.562e-02
# projection step=1, g=1.259e-04
# projection step=0, g=-1.119e-02
# projection step=1, g=6.402e-05
# projection step=0, g=-1.885e-02
# projection step=1, g=1.847e-04
# projection step=0, g=-3.678e-02
# projection step=1, g=7.300e-04
# projection step=0, g=4.343e-04
# projection step=0, g=4.536e-02
# projection step=1, g=9.433e-04
# projection step=0, g=6.654e-02
# projection step=1, g=1.954e-03
# projection step=2, g=1.848e-06
# projection step=0, g=3.804e-02
# projection step=1, g=6.724e-04
# projection step=0, g=-6.016e-03
# projection step=1, g=1.830e-05
# projection step=0, g=1.308e-03
# projection step=1, g=8.345e-07
# projection step=0, g=1.800e-02
# projection step=1, g=1.564e-04
# projection step=0, g=-7.228e-03
# projection step=1, g=2.646e-05
# projection step=0, g=-9.761e-04
# projection step=0, g=8.448e-03
# projection step=1, g=3.511e-05
# projection step=0, g=-1.202e-02
# projection step=1, g=7.403e-05
# projection step=0, g=3.551e-02
# projection step=1, g=5.887e-04
# projection step=0, g=-1.463e-02
# projection step=1, g=1.103e-04
# projection step=0, g=6.712e-02
# projection step=1, g=1.986e-03
# projection step=2, g=2.027e-06
# projection step=0, g=4.288e-02
# projection step=1, g=8.466e-04
# projection step=0, g=8.399e-02
# projection step=1, g=3.020e-03
# projection step=2, g=4.530e-06
# projection step=0, g=2.417e-03
# projection step=1, g=2.921e-06
# step=900, loss=-1.4139584302902222
# projection step=0, g=-1.046e-02
# projection step=1, g=5.591e-05
# projection step=0, g=2.679e-03
# projection step=1, g=3.576e-06
# projection step=0, g=2.328e-02
# projection step=1, g=2.589e-04
# projection step=0, g=7.060e-03
# projection step=1, g=2.456e-05
# projection step=0, g=1.843e-02
# projection step=1, g=1.637e-04
# projection step=0, g=1.001e-01
# projection step=1, g=4.176e-03
# projection step=2, g=8.643e-06
# projection step=0, g=-8.883e-04
# projection step=0, g=3.486e-02
# projection step=1, g=5.680e-04
# projection step=0, g=2.565e-02
# projection step=1, g=3.130e-04
# projection step=0, g=2.782e-02
# projection step=1, g=3.666e-04
# projection step=0, g=-2.428e-02
# projection step=1, g=3.098e-04
# projection step=0, g=1.113e-01
# projection step=1, g=5.066e-03
# projection step=2, g=1.276e-05
# projection step=0, g=-1.664e-02
# projection step=1, g=1.432e-04
# projection step=0, g=-6.898e-02
# projection step=1, g=2.760e-03
# projection step=2, g=3.755e-06
# projection step=0, g=4.223e-02
# projection step=1, g=8.222e-04
# projection step=0, g=8.674e-03
# projection step=1, g=3.695e-05
# projection step=0, g=-3.047e-04
# projection step=0, g=5.345e-02
# projection step=1, g=1.291e-03
# projection step=2, g=8.345e-07
# projection step=0, g=-1.777e-02
# projection step=1, g=1.638e-04
# projection step=0, g=3.376e-02
# projection step=1, g=5.339e-04
# projection step=0, g=4.604e-02
# projection step=1, g=9.707e-04
# projection step=0, g=1.045e-02
# projection step=1, g=5.352e-05
# projection step=0, g=5.138e-02
# projection step=1, g=1.197e-03
# projection step=2, g=7.153e-07
# projection step=0, g=4.035e-02
# projection step=1, g=7.532e-04
# projection step=0, g=3.533e-02
# projection step=1, g=5.828e-04
# projection step=0, g=2.759e-03
# projection step=1, g=3.815e-06
# projection step=0, g=1.499e-02
# projection step=1, g=1.090e-04
# projection step=0, g=1.495e-02
# projection step=1, g=1.086e-04
# projection step=0, g=4.042e-02
# projection step=1, g=7.559e-04
# projection step=0, g=4.408e-02
# projection step=1, g=8.929e-04
# projection step=0, g=1.023e-01
# projection step=1, g=4.348e-03
# projection step=2, g=9.358e-06
# projection step=0, g=1.038e-02
# projection step=1, g=5.281e-05
# projection step=0, g=-2.199e-02
# projection step=1, g=2.530e-04
# projection step=0, g=5.964e-02
# projection step=1, g=1.589e-03
# projection step=2, g=1.252e-06
# projection step=0, g=5.308e-02
# projection step=1, g=1.273e-03
# projection step=2, g=7.749e-07
# projection step=0, g=-4.945e-03
# projection step=1, g=1.234e-05
# projection step=0, g=4.605e-02
# projection step=1, g=9.711e-04
# projection step=0, g=4.324e-02
# projection step=1, g=8.603e-04
# projection step=0, g=3.331e-03
# projection step=1, g=5.543e-06
# projection step=0, g=6.117e-02
# projection step=1, g=1.667e-03
# projection step=2, g=1.371e-06
# projection step=0, g=1.972e-02
# projection step=1, g=1.870e-04
# projection step=0, g=3.045e-02
# projection step=1, g=4.371e-04
# projection step=0, g=-2.041e-03
# projection step=1, g=2.086e-06
# projection step=0, g=-1.334e-02
# projection step=1, g=9.137e-05
# projection step=0, g=-4.845e-02
# projection step=1, g=1.300e-03
# projection step=2, g=8.345e-07
# projection step=0, g=4.985e-02
# projection step=1, g=1.130e-03
# projection step=2, g=6.557e-07
# projection step=0, g=-4.052e-02
# projection step=1, g=8.932e-04
# projection step=0, g=3.383e-02
# projection step=1, g=5.360e-04
# projection step=0, g=-1.844e-02
# projection step=1, g=1.765e-04
# projection step=0, g=6.129e-03
# projection step=1, g=1.854e-05
# projection step=0, g=-4.196e-02
# projection step=1, g=9.609e-04
# projection step=0, g=2.167e-02
# projection step=1, g=2.250e-04
# projection step=0, g=8.301e-02
# projection step=1, g=2.955e-03
# projection step=2, g=4.292e-06
# projection step=0, g=-2.388e-02
# projection step=1, g=2.993e-04
# projection step=0, g=9.535e-03
# projection step=1, g=4.458e-05
# projection step=0, g=-9.656e-03
# projection step=1, g=4.756e-05
# projection step=0, g=-4.874e-02
# projection step=1, g=1.316e-03
# projection step=2, g=8.345e-07
# projection step=0, g=3.195e-02
# projection step=1, g=4.797e-04
# projection step=0, g=5.597e-02
# projection step=1, g=1.409e-03
# projection step=2, g=9.537e-07
# projection step=0, g=5.376e-03
# projection step=1, g=1.431e-05
# projection step=0, g=2.347e-02
# projection step=1, g=2.632e-04
# projection step=0, g=3.269e-02
# projection step=1, g=5.013e-04
# projection step=0, g=4.644e-02
# projection step=1, g=9.869e-04
# projection step=0, g=3.752e-02
# projection step=1, g=6.547e-04
# projection step=0, g=2.191e-02
# projection step=1, g=2.300e-04
# projection step=0, g=-1.555e-02
# projection step=1, g=1.248e-04
# projection step=0, g=-4.620e-03
# projection step=1, g=1.079e-05
# projection step=0, g=5.869e-02
# projection step=1, g=1.541e-03
# projection step=2, g=1.132e-06
# projection step=0, g=-2.269e-02
# projection step=1, g=2.697e-04
# projection step=0, g=4.983e-02
# projection step=1, g=1.129e-03
# projection step=2, g=5.960e-07
# projection step=0, g=3.128e-02
# projection step=1, g=4.604e-04
# projection step=0, g=5.889e-02
# projection step=1, g=1.551e-03
# projection step=2, g=1.192e-06
# projection step=0, g=-2.825e-02
# projection step=1, g=4.229e-04
# projection step=0, g=1.246e-02
# projection step=1, g=7.576e-05
# projection step=0, g=-1.281e-03
# projection step=1, g=8.345e-07
# projection step=0, g=-1.052e-02
# projection step=1, g=5.656e-05
# projection step=0, g=-3.420e-02
# projection step=1, g=6.276e-04
# projection step=0, g=2.461e-02
# projection step=1, g=2.887e-04
# projection step=0, g=5.788e-02
# projection step=1, g=1.501e-03
# projection step=2, g=1.132e-06
# projection step=0, g=4.719e-02
# projection step=1, g=1.018e-03
# projection step=2, g=4.768e-07
# projection step=0, g=6.200e-02
# projection step=1, g=1.710e-03
# projection step=2, g=1.490e-06
# projection step=0, g=5.482e-02
# projection step=1, g=1.354e-03
# projection step=2, g=9.537e-07
# projection step=0, g=-1.100e-02
# projection step=1, g=6.193e-05
# projection step=0, g=1.768e-03
# projection step=1, g=1.609e-06
# projection step=0, g=-1.633e-03
# projection step=1, g=1.311e-06
# projection step=0, g=-2.923e-03
# projection step=1, g=4.292e-06
# projection step=0, g=2.156e-02
# projection step=1, g=2.228e-04
# projection step=0, g=-3.063e-02
# projection step=1, g=4.997e-04
# projection step=0, g=4.235e-03
# projection step=1, g=8.941e-06
# projection step=0, g=-6.555e-02
# projection step=1, g=2.473e-03
# projection step=2, g=3.099e-06
# projection step=0, g=3.063e-03
# projection step=1, g=4.649e-06
# projection step=0, g=7.722e-03
# projection step=1, g=2.944e-05
# projection step=0, g=2.245e-02
# projection step=1, g=2.412e-04
# projection step=0, g=3.168e-02
# projection step=1, g=4.719e-04
# projection step=0, g=2.841e-02
# projection step=1, g=3.819e-04
# projection step=0, g=4.119e-02
# projection step=1, g=7.837e-04
# projection step=0, g=-2.515e-02
# projection step=1, g=3.330e-04
# projection step=0, g=-4.393e-03
# projection step=1, g=9.716e-06
# projection step=0, g=-7.789e-03
# projection step=1, g=3.082e-05
# [-0.7409646 -0.67159  ]
