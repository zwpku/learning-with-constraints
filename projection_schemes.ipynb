# %% [markdown]
# ## This notebook implements two constrained training scheme based on Newton's method.
#
# ### Newton's method
#
# ---
#
# ### Given $g: \mathbb{R}^N\rightarrow \mathbb{R}^k$, $x\in \mathbb{R}^N$, $v \in \mathbb{R}^{N\times k}$ find $\lambda\in \mathbb{R}^k$, such that
# $$
# \begin{aligned}
#    g(x + \tau v \lambda) = 0
#    \end{aligned}
# $$
#
# Netwon's method:
#
# $$
# \lambda_{n+1} = \lambda_n - \tau^{-1}(\nabla g(x_n + \tau v\lambda_n) v)^{-1} g(x_n + \tau v \lambda_n)
# $$

# %% [markdown]
# ### First, load neceesary packages

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import torch
import math 
import torch.nn as nn
import random
import itertools 
from tqdm import tqdm
import os
import time

# %% [markdown]
# ### Optimizer

# %%
def newton_projection(g, model, Y, v_direction, tau, res_tol=1e-3, max_newton_steps=100, verbose=True):       
    iter_step = 0
    converged = False
    projection_iter_steps = 0 
    print (v_direction)
    while iter_step < max_newton_steps:
        g_now = g(model, Y)
        
        if iter_step == 0:
            k = len(g_now)
            lam = np.zeros((k))
            
        if verbose:
            print (f'projection step={iter_step}, g={g_now.detach().item():.3e}, x={model.x.detach().numpy()}')
            
        if torch.linalg.norm(g_now) < res_tol:
            converged = True
            break

        grad_g = [torch.autograd.grad(g_now[idx], model.parameters(), 
                                      create_graph=True, retain_graph=True, allow_unused=True) for idx in range(k)]
               
        with torch.no_grad():
            mat = np.zeros((k, k))
            for i in range(k):
                for j in range(k):
                    for z1, z2 in zip(grad_g[i], v_direction[j]):
                        if z1 is not None: # and z2 is not None:
                            mat[i,j] += (z1 * z2).sum()
            dlam = -1.0 * np.linalg.solve(mat, g_now.numpy()) / tau
            lam += dlam
            for i in range(k):
                for param, z2 in zip(model.parameters(), v_direction[i]):
                    if z2 is not None:
                        param.add_(z2 * dlam[i] * tau)
                    
        iter_step += 1
    
    return converged, iter_step, lam 
        
class ProjectedSGD():
    
    def __init__(self, model, f, g, beta=1.0, tau=1e-1, res_tol=1e-3, max_newton_steps=100, verbose=True):
        self.f = f
        self.g = g
        self.tau = tau
        self.res_tol = res_tol
        self.max_newton_steps = max_newton_steps
        self.verbose = verbose
        self.model = model
        self.beta = beta
        self.X = None
        self.Y = None
        
    def reset_data(self, X, Y):
        self.X = X
        self.Y = Y
        
    def unconstrained_update(self):
        self.loss = self.f(self.model, self.X)
        self._grad_f = torch.autograd.grad(self.loss, self.model.parameters(), allow_unused=True)

        with torch.no_grad():
            for param, grad in zip(self.model.parameters(), self._grad_f):
                rn = torch.normal(torch.zeros(param.size()), torch.ones(param.size()))
                if grad is not None:
                    param.add_(-1.0 * grad * self.tau + math.sqrt(2.0 * self.tau / self.beta) * rn)       
                else :
                    param.add_(math.sqrt(2.0 * self.tau / self.beta) * rn)       
                    
    def projection_update(self):
        g_val = self.g(self.model, self.Y)
        grad_g_prev = [torch.autograd.grad(g_val[idx], self.model.parameters(), 
                                      create_graph=True, retain_graph=True, allow_unused=True) for idx in range(len(g_val))] 
        
        self.converged, self.projection_iter_steps, lam = newton_projection(self.g, self.model, self.Y,
                                                                            grad_g_prev, self.tau, 
                                                                            self.res_tol, self.max_newton_steps)
        
    def is_succeed(self):
        return self.converged
    
    def projection_steps(self):
        return self.projection_iter_steps

    def step(self, X, Y):
        self.reset_data(X, Y)
        self.unconstrained_update()
        self.projection_update()
        
class ProjectedLangevin():
    def __init__(self, model, f, g, tau=0.1, beta=1.0, alpha=0.5, res_tol=1e-5, max_newton_steps=100):
        self.model = model
        self.tau = tau
        self.beta = beta
        self.alpha = alpha
        self.res_tol = res_tol
        self.max_newton_steps = max_newton_steps
        self.p_list = []
        self.g = g
        self.f = f
        self.X = None
        self.Y = None
        
        for param in model.parameters():
            self.p_list.append(torch.zeros(param.size()))
    
    def reset_data(self, X, Y):
        self.X = X
        self.Y = Y
               
    def unconstrained_update(self):
        self.loss = self.f(self.model, self.X)
        # momnentum update
        grad_f = torch.autograd.grad(self.loss, self.model.parameters(), allow_unused=True)
        
        with torch.no_grad():
            for param, grad in zip (self.p_list, grad_f):
                param.add_(-0.5 * self.tau * grad)

            # position update
            for param, param_p in zip (self.model.parameters(), self.p_list):
                #print (param_p)
                param.add_(self.tau * param_p)
    
    def projection_momentum(self):
        g_val = self.g(self.model, self.Y)
        k = len(g_val)
        grad_g = [torch.autograd.grad(g_val[idx], self.model.parameters(), 
                                      create_graph=True, retain_graph=True, allow_unused=True) for idx in range(k)]
        with torch.no_grad():
            mat = np.zeros((k, k))
            for i in range(k):
                for j in range(k):
                    for z1, z2 in zip(grad_g[i], grad_g[j]):
                        mat[i,j] += (z1 * z2).sum()            
                        
            lam = np.zeros((k))
            for idx in range(k):
                for param, grad in zip (self.p_list, grad_g[idx]):        
                    lam[idx] += (param * grad).sum()
                    
            coeff = np.linalg.solve(mat, lam)    
                    
            for idx in range(k):
                for param, grad in zip (self.p_list, grad_g[idx]):        
                    param.add_(-1.0 * coeff[idx] * grad)
                                                    
    def momentum_refresh(self):
        for param in self.p_list:
            rn = torch.normal(torch.zeros(param.size()), torch.ones(param.size()))
            param.add_((self.alpha - 1.0) * param + math.sqrt((1-self.alpha**2)/self.beta) * rn)
        self.projection_momentum()
            
    def projection(self):
        g_val = self.g(self.model, self.Y)
        k = len(g_val)
        grad_g_prev = [torch.autograd.grad(g_val[idx], self.model.parameters(), 
                                      create_graph=True, retain_graph=True, allow_unused=True) for idx in range(k)] 
        
        #project position, x -> x_{1}
        converged, iter_steps, lam = newton_projection(self.g, self.model, self.Y, grad_g_prev, self.tau, 
                                                       self.res_tol, self.max_newton_steps)
        
        self.loss = self.f(self.model, self.X)
        # momnentum update: p_{1/2}->p_1
        grad_f = torch.autograd.grad(self.loss, self.model.parameters(), allow_unused=True)               
                
        with torch.no_grad():
            # modify momentum to get p_{1/2}
            for idx in range(k):
                for param, grad in zip (self.p_list, grad_g_prev[idx]):
                    param.add_(grad * lam[idx])

            # momnentum update: p_{1/2}->p_1
            for param, grad in zip (self.p_list, grad_f):
                param.add_(-0.5 * self.tau * grad)
        
        self.projection_momentum()
        
        # p_1 -> p_{1,-}
        for param in self.p_list:
            param *= -1.0

    def step(self, X, Y):
        self.reset_data(X, Y)
        self.momentum_refresh()
        self.unconstrained_update()
        self.projection()
#        self.momentum_refresh()

# %%
from test_problems import SimpleTest

problem = SimpleTest(1)
model = problem.create_model([1, -2.0])

g_val = problem.G(model, None)
grad_g_prev = [torch.autograd.grad(g_val[idx], model.parameters(), 
                                      create_graph=True, retain_graph=True, allow_unused=True) for idx in range(len(g_val))] 

print (grad_g_prev)
newton_projection(problem.G, model, None, grad_g_prev, tau=0.1, res_tol=1e-3)

print (model.x)
print (problem.G(model))
# Out:
# [(tensor([ 0., -1.], grad_fn=<AddBackward0>),)]
# [(tensor([ 0., -1.], grad_fn=<AddBackward0>),)]
# projection step=0, g=5.000e-01, x=[ 1. -2.]
# projection step=1, g=1.250e-01, x=[ 1.  -1.5]
# projection step=2, g=3.125e-02, x=[ 1.   -1.25]
# projection step=3, g=7.812e-03, x=[ 1.    -1.125]
# projection step=4, g=1.953e-03, x=[ 1.     -1.0625]
# projection step=5, g=4.883e-04, x=[ 1.      -1.03125]
# Parameter containing:
# tensor([ 1.0000, -1.0312], requires_grad=True)
# tensor([0.0005], grad_fn=<MulBackward0>)

# %% [markdown]
# ### Test 1

# %%
from test_problems import SimpleTest

problem = SimpleTest(1.0)

# make sure the initial parameters satisfy the constraint.
model = problem.create_model([1.0, -1.0])

opt = ProjectedSGD(model, problem.F, problem.G, tau=0.01, beta=20.0, verbose=True)
#opt = ProjectedLangevin(model, simple_f, simple_g, tau=0.3, beta=8.0, alpha=0.5)

n_steps = 1000
for idx in range(n_steps):
    opt.step(None, None)
    if idx % 100 == 0:
        print (f'step={idx}, loss={opt.loss.detach().numpy()}')
    #print (model.x.detach().numpy())
print (model.x.detach().numpy())
# Out:
# [(tensor([ 0.9379, -0.0242], grad_fn=<AddBackward0>),)]
# projection step=0, g=-3.693e-02, x=[ 0.96205753 -0.9862185 ]
# projection step=1, g=1.509e-03, x=[ 1.0014076 -0.9872322]
# projection step=2, g=2.146e-06, x=[ 0.99992114 -0.98719394]
# step=0, loss=0.0
# [(tensor([1.0778, 0.0418], grad_fn=<AddBackward0>),)]
# projection step=0, g=3.752e-02, x=[ 1.036003   -0.99419504]
# projection step=1, g=1.256e-03, x=[ 1.0012394  -0.99554354]
# projection step=2, g=1.609e-06, x=[ 0.99999195 -0.99559194]
# [(tensor([ 0.9919, -0.0023], grad_fn=<AddBackward0>),)]
# projection step=0, g=-5.769e-03, x=[ 0.9942112 -0.9965046]
# projection step=1, g=3.380e-05, x=[ 1.0000277 -0.9965181]
# [(tensor([1.0612, 0.0655], grad_fn=<AddBackward0>),)]
# projection step=0, g=-2.210e-03, x=[ 0.995633  -0.9300993]
# projection step=1, g=4.530e-06, x=[ 0.9977078  -0.92997116]
# [(tensor([ 0.9494, -0.0040], grad_fn=<AddBackward0>),)]
# projection step=0, g=-4.548e-02, x=[ 0.9534242 -0.9574364]
# projection step=1, g=2.285e-03, x=[ 1.0013299  -0.95763886]
# projection step=2, g=4.709e-06, x=[ 0.9991427 -0.9576296]
# [(tensor([1.1968, 0.1137], grad_fn=<AddBackward0>),)]
# projection step=0, g=9.299e-02, x=[ 1.0830725 -0.969355 ]
# projection step=1, g=6.520e-03, x=[ 1.0060692  -0.97667176]
# projection step=2, g=4.333e-05, x=[ 0.9997897 -0.9772684]
# [(tensor([1.0320, 0.0381], grad_fn=<AddBackward0>),)]
# projection step=0, g=-5.302e-03, x=[ 0.99395436 -0.9558733 ]
# projection step=1, g=2.730e-05, x=[ 0.99908507 -0.955684  ]
# [(tensor([1.0034, 0.0367], grad_fn=<AddBackward0>),)]
# projection step=0, g=-3.207e-02, x=[ 0.9667049 -0.929997 ]
# projection step=1, g=1.057e-03, x=[ 0.9986202 -0.9288295]
# projection step=2, g=1.013e-06, x=[ 0.9976337 -0.9288656]
# [(tensor([1.0195, 0.0264], grad_fn=<AddBackward0>),)]
# projection step=0, g=-6.528e-03, x=[ 0.99309963 -0.9667105 ]
# projection step=1, g=4.202e-05, x=[ 0.9994989  -0.96654487]
# [(tensor([1.0900, 0.0676], grad_fn=<AddBackward0>),)]
# projection step=0, g=2.491e-02, x=[ 1.0223746  -0.95476353]
# projection step=1, g=5.515e-04, x=[ 0.99960816 -0.95617574]
# [(tensor([ 0.8796, -0.0511], grad_fn=<AddBackward0>),)]
# projection step=0, g=-6.557e-02, x=[ 0.930724 -0.98183 ]
# projection step=1, g=5.208e-03, x=[ 1.0050175  -0.98614645]
# projection step=2, g=2.450e-05, x=[ 0.99992543 -0.9858506 ]
# [(tensor([1.1008, 0.0568], grad_fn=<AddBackward0>),)]
# projection step=0, g=4.660e-02, x=[ 1.0440191 -0.9871994]
# projection step=1, g=1.877e-03, x=[ 1.0017983  -0.98937863]
# projection step=2, g=3.576e-06, x=[ 0.99994874 -0.9894741 ]
# [(tensor([1.0693, 0.0408], grad_fn=<AddBackward0>),)]
# projection step=0, g=2.972e-02, x=[ 1.0284853  -0.98765373]
# projection step=1, g=8.004e-04, x=[ 1.000728  -0.9887136]
# [(tensor([1.1281, 0.0934], grad_fn=<AddBackward0>),)]
# projection step=0, g=3.962e-02, x=[ 1.0346501 -0.9412059]
# projection step=1, g=1.321e-03, x=[ 0.9997715 -0.944095 ]
# projection step=2, g=1.729e-06, x=[ 0.9985249  -0.94419825]
# [(tensor([1.0040, 0.0047], grad_fn=<AddBackward0>),)]
# projection step=0, g=-6.424e-04, x=[ 0.9993466  -0.99469626]
# [(tensor([1.0262, 0.0276], grad_fn=<AddBackward0>),)]
# projection step=0, g=-9.811e-04, x=[ 0.99863714 -0.9710386 ]
# [(tensor([1.0886, 0.0566], grad_fn=<AddBackward0>),)]
# projection step=0, g=3.410e-02, x=[ 1.0319898  -0.97542095]
# projection step=1, g=1.028e-03, x=[ 1.000747  -0.9770445]
# projection step=2, g=1.013e-06, x=[ 0.99974453 -0.9770966 ]
# [(tensor([1.0212, 0.0242], grad_fn=<AddBackward0>),)]
# projection step=0, g=-2.733e-03, x=[ 0.99696934 -0.97274303]
# projection step=1, g=7.331e-06, x=[ 0.99964374 -0.9726796 ]
# [(tensor([1.1193, 0.0983], grad_fn=<AddBackward0>),)]
# projection step=0, g=2.603e-02, x=[ 1.0209728 -0.9226438]
# projection step=1, g=5.813e-04, x=[ 0.997898  -0.9246709]
# [(tensor([1.0824, 0.0663], grad_fn=<AddBackward0>),)]
# projection step=0, g=1.849e-02, x=[ 1.0161626 -0.9499065]
# projection step=1, g=3.079e-04, x=[ 0.999146  -0.9509481]
# [(tensor([ 0.9686, -0.0292], grad_fn=<AddBackward0>),)]
# projection step=0, g=-1.714e-03, x=[ 0.99785686 -1.0270915 ]
# projection step=1, g=2.980e-06, x=[ 0.99962425 -1.0271448 ]
# [(tensor([ 0.8812, -0.0663], grad_fn=<AddBackward0>),)]
# projection step=0, g=-4.891e-02, x=[ 0.94751495 -1.0138031 ]
# projection step=1, g=2.825e-03, x=[ 1.0027056 -1.0179547]
# projection step=2, g=7.570e-06, x=[ 0.99984753 -1.0177398 ]
# [(tensor([ 0.9755, -0.0208], grad_fn=<AddBackward0>),)]
# projection step=0, g=-3.476e-03, x=[ 0.99630153 -1.0170853 ]
# projection step=1, g=1.240e-05, x=[ 0.9998628 -1.0171611]
# [(tensor([ 0.9864, -0.0150], grad_fn=<AddBackward0>),)]
# projection step=0, g=1.517e-03, x=[ 1.0014031 -1.0164009]
# projection step=1, g=2.265e-06, x=[ 0.99986595 -1.0163776 ]
# [(tensor([ 0.9439, -0.0497], grad_fn=<AddBackward0>),)]
# projection step=0, g=-5.104e-03, x=[ 0.99364   -1.0433618]
# projection step=1, g=2.760e-05, x=[ 0.9990319 -1.0436459]
# [(tensor([ 0.9385, -0.0489], grad_fn=<AddBackward0>),)]
# projection step=0, g=-1.130e-02, x=[ 0.9874259 -1.0363222]
# projection step=1, g=1.368e-04, x=[ 0.999433  -1.0369478]
# [(tensor([ 0.9189, -0.0898], grad_fn=<AddBackward0>),)]
# projection step=0, g=1.269e-02, x=[ 1.0086222 -1.0983758]
# projection step=1, g=1.697e-04, x=[ 0.9949452 -1.0970398]
# [(tensor([ 0.8912, -0.1048], grad_fn=<AddBackward0>),)]
# projection step=0, g=1.576e-03, x=[ 0.99607164 -1.1009166 ]
# projection step=1, g=2.742e-06, x=[ 0.9943279 -1.1007115]
# [(tensor([ 0.8232, -0.1471], grad_fn=<AddBackward0>),)]
# projection step=0, g=-1.836e-02, x=[ 0.97037965 -1.1175184 ]
# projection step=1, g=3.909e-04, x=[ 0.9919875 -1.1213804]
# [(tensor([ 0.9585, -0.0740], grad_fn=<AddBackward0>),)]
# projection step=0, g=3.571e-02, x=[ 1.0324515 -1.1064206]
# projection step=1, g=1.270e-03, x=[ 0.99541134 -1.1035621 ]
# projection step=2, g=1.848e-06, x=[ 0.9939931 -1.1034527]
# [(tensor([ 0.7838, -0.1893], grad_fn=<AddBackward0>),)]
# projection step=0, g=-8.651e-03, x=[ 0.9730686 -1.1623738]
# projection step=1, g=8.565e-05, x=[ 0.9834973 -1.1648927]
# [(tensor([ 0.8251, -0.1657], grad_fn=<AddBackward0>),)]
# projection step=0, g=4.591e-03, x=[ 0.9908241 -1.1565028]
# projection step=1, g=2.342e-05, x=[ 0.98547596 -1.155429  ]
# [(tensor([ 0.5499, -0.3387], grad_fn=<AddBackward0>),)]
# projection step=0, g=-4.787e-02, x=[ 0.8885588 -1.2272583]
# projection step=1, g=2.286e-03, x=[ 0.95167494 -1.2661363 ]
# projection step=2, g=4.351e-06, x=[ 0.9489243 -1.264442 ]
# [(tensor([ 0.7050, -0.2583], grad_fn=<AddBackward0>),)]
# projection step=0, g=-2.644e-03, x=[ 0.96332866 -1.2216126 ]
# projection step=1, g=7.629e-06, x=[ 0.96663463 -1.2228236 ]
# [(tensor([ 0.6617, -0.2963], grad_fn=<AddBackward0>),)]
# projection step=0, g=2.760e-03, x=[ 0.9579886 -1.2542605]
# projection step=1, g=7.868e-06, x=[ 0.9545146 -1.2527051]
# [(tensor([ 0.6764, -0.3036], grad_fn=<AddBackward0>),)]
# projection step=0, g=2.639e-02, x=[ 0.98009336 -1.2837381 ]
# projection step=1, g=6.874e-04, x=[ 0.9476214 -1.269162 ]
# [(tensor([ 0.5658, -0.3570], grad_fn=<AddBackward0>),)]
# projection step=0, g=-1.049e-02, x=[ 0.92279255 -1.2798253 ]
# projection step=1, g=9.990e-05, x=[ 0.936054  -1.2881942]
# [(tensor([ 0.5719, -0.3366], grad_fn=<AddBackward0>),)]
# projection step=0, g=-3.068e-02, x=[ 0.9084814 -1.2450981]
# projection step=1, g=9.277e-04, x=[ 0.94831914 -1.2685478 ]
# [(tensor([ 0.7530, -0.2504], grad_fn=<AddBackward0>),)]
# projection step=0, g=3.483e-02, x=[ 1.0034676 -1.253911 ]
# projection step=1, g=1.254e-03, x=[ 0.96181524 -1.2400582 ]
# projection step=2, g=1.907e-06, x=[ 0.9601997 -1.2395209]
# [(tensor([ 0.6515, -0.2819], grad_fn=<AddBackward0>),)]
# projection step=0, g=-2.465e-02, x=[ 0.933393  -1.2153181]
# projection step=1, g=6.711e-04, x=[ 0.96525955 -1.2291085 ]
# [(tensor([ 0.7826, -0.2672], grad_fn=<AddBackward0>),)]
# projection step=0, g=8.682e-02, x=[ 1.0498728 -1.3171012]
# projection step=1, g=7.076e-03, x=[ 0.9505214 -1.2831784]
# projection step=2, g=6.706e-05, x=[ 0.94084764 -1.2798754 ]
# [(tensor([ 0.6887, -0.2935], grad_fn=<AddBackward0>),)]
# projection step=0, g=2.543e-02, x=[ 0.9822032 -1.2757103]
# projection step=1, g=6.493e-04, x=[ 0.9509482 -1.2623901]
# [(tensor([ 0.7859, -0.2278], grad_fn=<AddBackward0>),)]
# projection step=0, g=3.968e-02, x=[ 1.0136521 -1.2414023]
# projection step=1, g=1.632e-03, x=[ 0.9670736 -1.2279041]
# projection step=2, g=3.278e-06, x=[ 0.96498626 -1.2272992 ]
# [(tensor([ 0.7479, -0.2419], grad_fn=<AddBackward0>),)]
# projection step=0, g=1.908e-02, x=[ 0.98976856 -1.2316628 ]
# projection step=1, g=3.887e-04, x=[ 0.9666757 -1.2241936]
# [(tensor([ 0.6870, -0.2557], grad_fn=<AddBackward0>),)]
# projection step=0, g=-2.298e-02, x=[ 0.9426777 -1.1983931]
# projection step=1, g=6.019e-04, x=[ 0.9720636 -1.2093318]
# [(tensor([ 0.8031, -0.2038], grad_fn=<AddBackward0>),)]
# projection step=0, g=2.767e-02, x=[ 1.0068872 -1.2106379]
# projection step=1, g=8.155e-04, x=[ 0.97452027 -1.2024267 ]
# [(tensor([ 0.5720, -0.3467], grad_fn=<AddBackward0>),)]
# projection step=0, g=-1.790e-02, x=[ 0.9187065 -1.265368 ]
# projection step=1, g=3.026e-04, x=[ 0.94159555 -1.2792388 ]
# [(tensor([ 0.6342, -0.2805], grad_fn=<AddBackward0>),)]
# projection step=0, g=-4.235e-02, x=[ 0.9146833 -1.1951542]
# projection step=1, g=2.045e-03, x=[ 0.9705296 -1.2198514]
# projection step=2, g=3.934e-06, x=[ 0.9680706 -1.218764 ]
# [(tensor([ 0.7857, -0.2201], grad_fn=<AddBackward0>),)]
# projection step=0, g=3.003e-02, x=[ 1.0057983 -1.2258856]
# projection step=1, g=9.537e-04, x=[ 0.9703537 -1.2159572]
# [(tensor([ 0.7847, -0.2461], grad_fn=<AddBackward0>),)]
# projection step=0, g=6.161e-02, x=[ 1.0308435 -1.2769842]
# projection step=1, g=3.758e-03, x=[ 0.9593607 -1.2545619]
# projection step=2, g=1.812e-05, x=[ 0.9543943 -1.2530041]
# [(tensor([ 0.6652, -0.3073], grad_fn=<AddBackward0>),)]
# projection step=0, g=2.002e-02, x=[ 0.9724372 -1.279693 ]
# projection step=1, g=3.967e-04, x=[ 0.9476324 -1.2682353]
# [(tensor([ 0.6047, -0.3649], grad_fn=<AddBackward0>),)]
# projection step=0, g=3.661e-02, x=[ 0.96957237 -1.3344659 ]
# projection step=1, g=1.140e-03, x=[ 0.9251911 -1.307684 ]
# projection step=2, g=1.192e-06, x=[ 0.9237177 -1.3067948]
# [(tensor([ 0.5169, -0.3928], grad_fn=<AddBackward0>),)]
# projection step=0, g=-9.100e-03, x=[ 0.9096762 -1.302474 ]
# projection step=1, g=6.586e-05, x=[ 0.92083603 -1.3109548 ]
# [(tensor([ 0.4893, -0.4416], grad_fn=<AddBackward0>),)]
# projection step=0, g=3.080e-02, x=[ 0.93091315 -1.3724952 ]
# projection step=1, g=6.074e-04, x=[ 0.896225  -1.3411919]
# [(tensor([ 0.3486, -0.5096], grad_fn=<AddBackward0>),)]
# projection step=0, g=-1.912e-03, x=[ 0.8581883 -1.3677857]
# projection step=1, g=1.907e-06, x=[ 0.8599364 -1.3703413]
# [(tensor([ 0.3493, -0.5107], grad_fn=<AddBackward0>),)]
# projection step=0, g=1.822e-04, x=[ 0.85999405 -1.3706551 ]
# [(tensor([ 0.2805, -0.5536], grad_fn=<AddBackward0>),)]
# projection step=0, g=1.165e-03, x=[ 0.83415306 -1.3877935 ]
# projection step=1, g=6.557e-07, x=[ 0.833305  -1.3861197]
# [(tensor([ 0.3071, -0.5330], grad_fn=<AddBackward0>),)]
# projection step=0, g=-5.033e-03, x=[ 0.84013635 -1.3731505 ]
# projection step=1, g=1.287e-05, x=[ 0.84422135 -1.3802401 ]
# [(tensor([ 0.3011, -0.5496], grad_fn=<AddBackward0>),)]
# projection step=0, g=1.289e-02, x=[ 0.8507181 -1.4003235]
# projection step=1, g=8.219e-05, x=[ 0.8408324 -1.3822798]
# [(tensor([ 0.2205, -0.5951], grad_fn=<AddBackward0>),)]
# projection step=0, g=9.656e-03, x=[ 0.8155746 -1.4106795]
# projection step=1, g=5.436e-05, x=[ 0.81028897 -1.3964123 ]
# [(tensor([ 0.2982, -0.5517], grad_fn=<AddBackward0>),)]
# projection step=0, g=1.333e-02, x=[ 0.8498724 -1.4015714]
# projection step=1, g=8.792e-05, x=[ 0.8397679 -1.3828753]
# [(tensor([ 0.1657, -0.6204], grad_fn=<AddBackward0>),)]
# projection step=0, g=1.336e-03, x=[ 0.7860235 -1.4063776]
# projection step=1, g=1.192e-06, x=[ 0.78548664 -1.4043672 ]
# [(tensor([ 0.2265, -0.5678], grad_fn=<AddBackward0>),)]
# projection step=0, g=-2.334e-02, x=[ 0.7942852 -1.3621107]
# projection step=1, g=3.273e-04, x=[ 0.80843025 -1.3975781 ]
# [(tensor([ 0.1804, -0.6045], grad_fn=<AddBackward0>),)]
# projection step=0, g=-9.241e-03, x=[ 0.7849263 -1.389417 ]
# projection step=1, g=5.722e-05, x=[ 0.789116  -1.4034534]
# [(tensor([ 0.0569, -0.6661], grad_fn=<AddBackward0>),)]
# projection step=0, g=-1.679e-02, x=[ 0.7229863 -1.3890979]
# projection step=1, g=2.643e-04, x=[ 0.7251232 -1.414126 ]
# [(tensor([-0.0457, -0.7492], grad_fn=<AddBackward0>),)]
# projection step=0, g=2.807e-02, x=[ 0.7034547 -1.4526441]
# projection step=1, g=7.868e-04, x=[ 0.7057331 -1.4153205]
# [(tensor([-0.1292, -0.7888], grad_fn=<AddBackward0>),)]
# projection step=0, g=2.870e-02, x=[ 0.6596449 -1.4484837]
# projection step=1, g=8.669e-04, x=[ 0.6654477 -1.4130527]
# [(tensor([-0.1296, -0.7815], grad_fn=<AddBackward0>),)]
# projection step=0, g=1.780e-02, x=[ 0.65187484 -1.4333277 ]
# projection step=1, g=3.409e-04, x=[ 0.65555173 -1.4111533 ]
# [(tensor([-0.0182, -0.7381], grad_fn=<AddBackward0>),)]
# projection step=0, g=3.154e-02, x=[ 0.7199012 -1.4580227]
# projection step=1, g=9.580e-04, x=[ 0.7209554 -1.4153179]
# [(tensor([ 0.1595, -0.5912], grad_fn=<AddBackward0>),)]
# projection step=0, g=-4.350e-02, x=[ 0.75069636 -1.3418486 ]
# projection step=1, g=1.425e-03, x=[ 0.76920635 -1.4104329 ]
# projection step=2, g=1.311e-06, x=[ 0.76863724 -1.4083242 ]
# [(tensor([ 0.0211, -0.7120], grad_fn=<AddBackward0>),)]
# projection step=0, g=2.219e-02, x=[ 0.7331147 -1.4450933]
# projection step=1, g=4.567e-04, x=[ 0.7321905 -1.4139606]
# [(tensor([ 0.0215, -0.7188], grad_fn=<AddBackward0>),)]
# projection step=0, g=3.230e-02, x=[ 0.74026763 -1.4590214 ]
# projection step=1, g=9.495e-04, x=[ 0.73892367 -1.4141206 ]
# [(tensor([-0.0300, -0.7111], grad_fn=<AddBackward0>),)]
# projection step=0, g=-1.515e-02, x=[ 0.6811687 -1.3922992]
# projection step=1, g=2.460e-04, x=[ 0.6802726 -1.4135674]
# [(tensor([-0.0392, -0.7332], grad_fn=<AddBackward0>),)]
# projection step=0, g=9.560e-03, x=[ 0.6939746 -1.4271315]
# projection step=1, g=9.406e-05, x=[ 0.6946695 -1.4141293]
# [(tensor([-0.0844, -0.7839], grad_fn=<AddBackward0>),)]
# projection step=0, g=5.191e-02, x=[ 0.69952905 -1.4834213 ]
# projection step=1, g=2.654e-03, x=[ 0.70657474 -1.4179537 ]
# projection step=2, g=8.583e-06, x=[ 0.70697594 -1.4142257 ]
# [(tensor([-0.0024, -0.7232], grad_fn=<AddBackward0>),)]
# projection step=0, g=2.125e-02, x=[ 0.72075903 -1.4439551 ]
# projection step=1, g=4.348e-04, x=[ 0.72085804 -1.4145677 ]
# [(tensor([-0.0555, -0.7501], grad_fn=<AddBackward0>),)]
# projection step=0, g=2.254e-02, x=[ 0.6945638 -1.444675 ]
# projection step=1, g=5.177e-04, x=[ 0.6967771 -1.4147862]
# [(tensor([-0.0614, -0.7619], grad_fn=<AddBackward0>),)]
# projection step=0, g=3.559e-02, x=[ 0.7005038 -1.4623935]
# projection step=1, g=1.265e-03, x=[ 0.7042433 -1.415981 ]
# projection step=2, g=1.907e-06, x=[ 0.70438635 -1.4142058 ]
# [(tensor([-0.0663, -0.7575], grad_fn=<AddBackward0>),)]
# projection step=0, g=2.581e-02, x=[ 0.6912371 -1.4487346]
# projection step=1, g=6.802e-04, x=[ 0.6941944 -1.4149264]
# [(tensor([ 0.0938, -0.6622], grad_fn=<AddBackward0>),)]
# projection step=0, g=4.997e-03, x=[ 0.75597024 -1.4181662 ]
# projection step=1, g=2.068e-05, x=[ 0.75492257 -1.410768  ]
# [(tensor([ 0.0808, -0.6795], grad_fn=<AddBackward0>),)]
# projection step=0, g=1.997e-02, x=[ 0.7603639 -1.4399133]
# projection step=1, g=3.319e-04, x=[ 0.7569177 -1.4109355]
# [(tensor([ 0.0263, -0.6992], grad_fn=<AddBackward0>),)]
# projection step=0, g=7.654e-03, x=[ 0.72553885 -1.4247541 ]
# projection step=1, g=5.543e-05, x=[ 0.7251273 -1.4138227]
# [(tensor([-0.1404, -0.8161], grad_fn=<AddBackward0>),)]
# projection step=0, g=6.131e-02, x=[ 0.6757134 -1.49182  ]
# projection step=1, g=3.735e-03, x=[ 0.6882654 -1.4188552]
# projection step=2, g=1.806e-05, x=[ 0.6891362 -1.413793 ]
# [(tensor([-0.0718, -0.7425], grad_fn=<AddBackward0>),)]
# projection step=0, g=5.164e-04, x=[ 0.6706713 -1.4131218]
# [(tensor([-0.0220, -0.7196], grad_fn=<AddBackward0>),)]
# projection step=0, g=2.245e-03, x=[ 0.6976227 -1.4172142]
# projection step=1, g=5.126e-06, x=[ 0.69771785 -1.4140977 ]
# [(tensor([-0.1022, -0.7790], grad_fn=<AddBackward0>),)]
# projection step=0, g=3.245e-02, x=[ 0.676797  -1.4558012]
# projection step=1, g=1.087e-03, x=[ 0.68217   -1.4148493]
# projection step=2, g=1.371e-06, x=[ 0.682363  -1.4133784]
# [(tensor([-0.0702, -0.7300], grad_fn=<AddBackward0>),)]
# projection step=0, g=-1.586e-02, x=[ 0.6598364 -1.3898281]
# projection step=1, g=2.806e-04, x=[ 0.657767 -1.411361]
# [(tensor([-0.0773, -0.7342], grad_fn=<AddBackward0>),)]
# projection step=0, g=-1.467e-02, x=[ 0.6569202 -1.3911594]
# projection step=1, g=2.409e-04, x=[ 0.6548387 -1.410926 ]
# [(tensor([-0.1478, -0.7942], grad_fn=<AddBackward0>),)]
# projection step=0, g=2.421e-02, x=[ 0.6463318 -1.4404827]
# projection step=1, g=6.258e-04, x=[ 0.65181625 -1.4110179 ]
# [(tensor([-0.0312, -0.7179], grad_fn=<AddBackward0>),)]
# projection step=0, g=-6.527e-03, x=[ 0.68670064 -1.4046057 ]
# projection step=1, g=4.494e-05, x=[ 0.6863062 -1.4136807]
# [(tensor([-0.1779, -0.8097], grad_fn=<AddBackward0>),)]
# projection step=0, g=2.745e-02, x=[ 0.631855  -1.4415796]
# projection step=1, g=8.030e-04, x=[ 0.63895833 -1.4092429 ]
# [(tensor([-0.1454, -0.7852], grad_fn=<AddBackward0>),)]
# projection step=0, g=1.294e-02, x=[ 0.63981503 -1.4249957 ]
# projection step=1, g=1.826e-04, x=[ 0.6427641 -1.4090666]
# [(tensor([-0.1878, -0.7937], grad_fn=<AddBackward0>),)]
# projection step=0, g=-1.485e-03, x=[ 0.60589796 -1.3995714 ]
# projection step=1, g=2.503e-06, x=[ 0.60547876 -1.4013433 ]
# [(tensor([-0.3102, -0.8712], grad_fn=<AddBackward0>),)]
# projection step=0, g=3.684e-02, x=[ 0.56099474 -1.4321834 ]
# projection step=1, g=1.384e-03, x=[ 0.5743582 -1.3946518]
# projection step=2, g=2.325e-06, x=[ 0.5749012 -1.3931268]
# [(tensor([-0.2456, -0.8334], grad_fn=<AddBackward0>),)]
# projection step=0, g=2.003e-02, x=[ 0.58779794 -1.4211985 ]
# projection step=1, g=4.312e-04, x=[ 0.5943153 -1.3990834]
# [(tensor([-0.1902, -0.7916], grad_fn=<AddBackward0>),)]
# projection step=0, g=-5.842e-03, x=[ 0.6013994 -1.3930024]
# projection step=1, g=3.886e-05, x=[ 0.59972304 -1.3999792 ]
# [(tensor([-0.3089, -0.8587], grad_fn=<AddBackward0>),)]
# projection step=0, g=1.981e-02, x=[ 0.54978544 -1.408482  ]
# projection step=1, g=4.128e-04, x=[ 0.5571344 -1.3880537]
# [(tensor([-0.4216, -0.9239], grad_fn=<AddBackward0>),)]
# projection step=0, g=5.292e-02, x=[ 0.50224596 -1.4261402 ]
# projection step=1, g=2.617e-03, x=[ 0.52387923 -1.3787385 ]
# projection step=2, g=7.927e-06, x=[ 0.52506655 -1.376137  ]
# [(tensor([-0.3617, -0.8790], grad_fn=<AddBackward0>),)]
# projection step=0, g=2.014e-02, x=[ 0.5173067 -1.3963279]
# projection step=1, g=4.151e-04, x=[ 0.5253704 -1.3767318]
# [(tensor([-0.3082, -0.8483], grad_fn=<AddBackward0>),)]
# projection step=0, g=5.658e-03, x=[ 0.5400686 -1.3883852]
# projection step=1, g=3.451e-05, x=[ 0.5422093 -1.3824939]
# [(tensor([-0.4031, -0.9100], grad_fn=<AddBackward0>),)]
# projection step=0, g=4.247e-02, x=[ 0.50687104 -1.4168302 ]
# projection step=1, g=1.734e-03, x=[ 0.5241551 -1.377812 ]
# projection step=2, g=3.338e-06, x=[ 0.5249237 -1.3760769]
# step=100, loss=-0.840284526348114
# [(tensor([-0.3728, -0.8824], grad_fn=<AddBackward0>),)]
# projection step=0, g=1.909e-02, x=[ 0.50952727 -1.3918914 ]
# projection step=1, g=3.712e-04, x=[ 0.517285  -1.3735318]
# [(tensor([-0.3879, -0.8694], grad_fn=<AddBackward0>),)]
# projection step=0, g=-6.142e-03, x=[ 0.4815156 -1.3509165]
# projection step=1, g=3.982e-05, x=[ 0.47888675 -1.3568088 ]
# [(tensor([-0.5902, -0.9866], grad_fn=<AddBackward0>),)]
# projection step=0, g=6.530e-02, x=[ 0.39641613 -1.3830589 ]
# projection step=1, g=3.460e-03, x=[ 0.42557618 -1.334314  ]
# projection step=2, g=1.222e-05, x=[ 0.4273041 -1.3314255]
# [(tensor([-0.4339, -0.8761], grad_fn=<AddBackward0>),)]
# projection step=0, g=-1.844e-02, x=[ 0.4422276 -1.3183277]
# projection step=1, g=3.545e-04, x=[ 0.4338562 -1.3352317]
# [(tensor([-0.4700, -0.9263], grad_fn=<AddBackward0>),)]
# projection step=0, g=3.317e-02, x=[ 0.45633054 -1.3826681 ]
# projection step=1, g=1.026e-03, x=[ 0.47077888 -1.3541919 ]
# projection step=2, g=1.013e-06, x=[ 0.47125512 -1.3532532 ]
# [(tensor([-0.3817, -0.8418], grad_fn=<AddBackward0>),)]
# projection step=0, g=-3.982e-02, x=[ 0.46012232 -1.3019388 ]
# projection step=1, g=1.784e-03, x=[ 0.44233367 -1.3411711 ]
# projection step=2, g=3.099e-06, x=[ 0.4430651 -1.339558 ]
# [(tensor([-0.3828, -0.8526], grad_fn=<AddBackward0>),)]
# projection step=0, g=-2.610e-02, x=[ 0.46988165 -1.3225292 ]
# projection step=1, g=7.468e-04, x=[ 0.45844418 -1.3480073 ]
# [(tensor([-0.4971, -0.9371], grad_fn=<AddBackward0>),)]
# projection step=0, g=3.594e-02, x=[ 0.44006714 -1.3772043 ]
# projection step=1, g=1.175e-03, x=[ 0.4559437 -1.3472719]
# projection step=2, g=1.431e-06, x=[ 0.4564992 -1.3462247]
# [(tensor([-0.5036, -0.9378], grad_fn=<AddBackward0>),)]
# projection step=0, g=3.391e-02, x=[ 0.4341045 -1.371858 ]
# projection step=1, g=1.044e-03, x=[ 0.44917968 -1.3437892 ]
# projection step=2, g=1.132e-06, x=[ 0.44967437 -1.3428682 ]
# [(tensor([-0.3784, -0.8590], grad_fn=<AddBackward0>),)]
# projection step=0, g=-1.554e-02, x=[ 0.48060143 -1.3396319 ]
# projection step=1, g=2.605e-04, x=[ 0.47392547 -1.3547863 ]
# [(tensor([-0.4516, -0.9135], grad_fn=<AddBackward0>),)]
# projection step=0, g=2.387e-02, x=[ 0.4618719 -1.3753296]
# projection step=1, g=5.460e-04, x=[ 0.47225124 -1.3543345 ]
# [(tensor([-0.4828, -0.9229], grad_fn=<AddBackward0>),)]
# projection step=0, g=2.277e-02, x=[ 0.44016737 -1.3630958 ]
# projection step=1, g=4.867e-04, x=[ 0.45030096 -1.3437227 ]
# [(tensor([-0.5146, -0.9575], grad_fn=<AddBackward0>),)]
# projection step=0, g=5.646e-02, x=[ 0.4428911 -1.400369 ]
# projection step=1, g=2.776e-03, x=[ 0.4674794 -1.3546182]
# projection step=2, g=8.285e-06, x=[ 0.4688203 -1.3521233]
# [(tensor([-0.4071, -0.8595], grad_fn=<AddBackward0>),)]
# projection step=0, g=-2.830e-02, x=[ 0.4524069 -1.3118985]
# projection step=1, g=8.665e-04, x=[ 0.43966874 -1.338793  ]
# [(tensor([-0.4013, -0.8635], grad_fn=<AddBackward0>),)]
# projection step=0, g=-2.039e-02, x=[ 0.46218583 -1.3256695 ]
# projection step=1, g=4.453e-04, x=[ 0.4531608 -1.345089 ]
# [(tensor([-0.4727, -0.9020], grad_fn=<AddBackward0>),)]
# projection step=0, g=-1.028e-03, x=[ 0.42934763 -1.3313482 ]
# projection step=1, g=1.013e-06, x=[ 0.42887917 -1.3322421 ]
# [(tensor([-0.5075, -0.9314], grad_fn=<AddBackward0>),)]
# projection step=0, g=2.356e-02, x=[ 0.4238815 -1.355249 ]
# projection step=1, g=5.106e-04, x=[ 0.43450975 -1.3357435 ]
# [(tensor([-0.4661, -0.9033], grad_fn=<AddBackward0>),)]
# projection step=0, g=3.532e-03, x=[ 0.43720835 -1.3404871 ]
# projection step=1, g=1.228e-05, x=[ 0.43880165 -1.3373992 ]
# [(tensor([-0.4057, -0.8626], grad_fn=<AddBackward0>),)]
# projection step=0, g=-2.361e-02, x=[ 0.45688647 -1.3194637 ]
# projection step=1, g=5.985e-04, x=[ 0.44634593 -1.341875  ]
# [(tensor([-0.4872, -0.9220], grad_fn=<AddBackward0>),)]
# projection step=0, g=1.962e-02, x=[ 0.43487254 -1.3569    ]
# projection step=1, g=3.619e-04, x=[ 0.44366384 -1.3402609 ]
# [(tensor([-0.5216, -0.9283], grad_fn=<AddBackward0>),)]
# projection step=0, g=1.361e-02, x=[ 0.40673348 -1.3350556 ]
# projection step=1, g=1.709e-04, x=[ 0.412993  -1.3239149]
# [(tensor([-0.5867, -0.9772], grad_fn=<AddBackward0>),)]
# projection step=0, g=5.373e-02, x=[ 0.3905351 -1.367742 ]
# projection step=1, g=2.386e-03, x=[ 0.4147971 -1.3273293]
# projection step=2, g=5.662e-06, x=[ 0.41597953 -1.3253597 ]
# [(tensor([-0.5701, -0.9531], grad_fn=<AddBackward0>),)]
# projection step=0, g=2.755e-02, x=[ 0.3829773 -1.3360888]
# projection step=1, g=6.597e-04, x=[ 0.3957098 -1.3148035]
# [(tensor([-0.6242, -0.9739], grad_fn=<AddBackward0>),)]
# projection step=0, g=3.537e-02, x=[ 0.3497039 -1.3235862]
# projection step=1, g=1.028e-03, x=[ 0.3662034 -1.2978426]
# projection step=2, g=9.537e-07, x=[ 0.36671266 -1.297048  ]
# [(tensor([-0.6808, -0.9894], grad_fn=<AddBackward0>),)]
# projection step=0, g=3.713e-02, x=[ 0.30867523 -1.298105  ]
# projection step=1, g=1.078e-03, x=[ 0.32619715 -1.2726381 ]
# projection step=2, g=9.537e-07, x=[ 0.32673705 -1.2718533 ]
# [(tensor([-0.6230, -0.9314], grad_fn=<AddBackward0>),)]
# projection step=0, g=-1.875e-02, x=[ 0.30831844 -1.2396828 ]
# projection step=1, g=3.127e-04, x=[ 0.2990146 -1.2535907]
# [(tensor([-0.6827, -0.9696], grad_fn=<AddBackward0>),)]
# projection step=0, g=1.118e-02, x=[ 0.2869021 -1.25646  ]
# projection step=1, g=1.010e-04, x=[ 0.29232895 -1.2487524 ]
# [(tensor([-0.6735, -0.9757], grad_fn=<AddBackward0>),)]
# projection step=0, g=2.163e-02, x=[ 0.30215237 -1.2778395 ]
# projection step=1, g=3.758e-04, x=[ 0.31251726 -1.2628249 ]
# [(tensor([-0.6729, -0.9774], grad_fn=<AddBackward0>),)]
# projection step=0, g=2.401e-02, x=[ 0.3045058 -1.2818997]
# projection step=1, g=4.619e-04, x=[ 0.31598023 -1.2652327 ]
# [(tensor([-0.6458, -0.9548], grad_fn=<AddBackward0>),)]
# projection step=0, g=3.613e-03, x=[ 0.30903924 -1.2638798 ]
# projection step=1, g=1.097e-05, x=[ 0.31079513 -1.2612836 ]
# [(tensor([-0.5433, -0.8833], grad_fn=<AddBackward0>),)]
# projection step=0, g=-5.210e-02, x=[ 0.34001237 -1.2232983 ]
# projection step=1, g=2.735e-03, x=[ 0.3136915 -1.2660923]
# projection step=2, g=6.139e-06, x=[ 0.31494188 -1.2640593 ]
# [(tensor([-0.7291, -1.0042], grad_fn=<AddBackward0>),)]
# projection step=0, g=4.198e-02, x=[ 0.27503654 -1.2791896 ]
# projection step=1, g=1.314e-03, x=[ 0.2949149 -1.2518127]
# projection step=2, g=1.490e-06, x=[ 0.29557863 -1.2508986 ]
# [(tensor([-0.6607, -0.9333], grad_fn=<AddBackward0>),)]
# projection step=0, g=-2.738e-02, x=[ 0.27254015 -1.2057917 ]
# projection step=1, g=6.530e-04, x=[ 0.2587035 -1.225336 ]
# [(tensor([-0.7100, -0.9696], grad_fn=<AddBackward0>),)]
# projection step=0, g=3.694e-03, x=[ 0.25952643 -1.2290803 ]
# projection step=1, g=1.085e-05, x=[ 0.26134276 -1.2266    ]
# [(tensor([-0.7033, -0.9766], grad_fn=<AddBackward0>),)]
# projection step=0, g=1.426e-02, x=[ 0.27332962 -1.2499632 ]
# projection step=1, g=1.608e-04, x=[ 0.28025416 -1.2403475 ]
# [(tensor([-0.6027, -0.8961], grad_fn=<AddBackward0>),)]
# projection step=0, g=-5.544e-02, x=[ 0.29341146 -1.1895274 ]
# projection step=1, g=2.949e-03, x=[ 0.2647598 -1.2321274]
# projection step=2, g=6.795e-06, x=[ 0.26613727 -1.2300794 ]
# [(tensor([-0.7412, -1.0024], grad_fn=<AddBackward0>),)]
# projection step=0, g=3.647e-02, x=[ 0.26118276 -1.2635432 ]
# projection step=1, g=9.884e-04, x=[ 0.27857697 -1.2400194 ]
# [(tensor([-0.5924, -0.9134], grad_fn=<AddBackward0>),)]
# projection step=0, g=-3.139e-02, x=[ 0.32091913 -1.2342778 ]
# projection step=1, g=9.185e-04, x=[ 0.3052268 -1.2584705]
# [(tensor([-0.6608, -0.9667], grad_fn=<AddBackward0>),)]
# projection step=0, g=1.405e-02, x=[ 0.30589154 -1.2726014 ]
# projection step=1, g=1.619e-04, x=[ 0.312662  -1.2626969]
# [(tensor([-0.5537, -0.8977], grad_fn=<AddBackward0>),)]
# projection step=0, g=-3.795e-02, x=[ 0.34397903 -1.241634  ]
# projection step=1, g=1.404e-03, x=[ 0.32509068 -1.2722571 ]
# projection step=2, g=1.669e-06, x=[ 0.3257414 -1.2712021]
# [(tensor([-0.5741, -0.9299], grad_fn=<AddBackward0>),)]
# projection step=0, g=-4.366e-03, x=[ 0.3557843 -1.285669 ]
# projection step=1, g=1.734e-05, x=[ 0.3536855 -1.2890685]
# [(tensor([-0.5826, -0.9052], grad_fn=<AddBackward0>),)]
# projection step=0, g=-3.824e-02, x=[ 0.32264525 -1.227859  ]
# projection step=1, g=1.390e-03, x=[ 0.30341864 -1.257734  ]
# projection step=2, g=1.550e-06, x=[ 0.3040702 -1.2567215]
# [(tensor([-0.6949, -0.9901], grad_fn=<AddBackward0>),)]
# projection step=0, g=3.378e-02, x=[ 0.29526088 -1.2854047 ]
# projection step=1, g=8.854e-04, x=[ 0.31130356 -1.2625453 ]
# [(tensor([-0.7874, -1.0223], grad_fn=<AddBackward0>),)]
# projection step=0, g=5.011e-02, x=[ 0.23486596 -1.2571483 ]
# projection step=1, g=1.764e-03, x=[ 0.2585637 -1.2263821]
# projection step=2, g=2.563e-06, x=[ 0.259461  -1.2252172]
# [(tensor([-0.7220, -0.9819], grad_fn=<AddBackward0>),)]
# projection step=0, g=1.579e-02, x=[ 0.25987405 -1.2417362 ]
# projection step=1, g=1.935e-04, x=[ 0.26755115 -1.2312957 ]
# [(tensor([-0.6968, -0.9504], grad_fn=<AddBackward0>),)]
# projection step=0, g=-1.616e-02, x=[ 0.25366822 -1.2041099 ]
# projection step=1, g=2.165e-04, x=[ 0.24556255 -1.2151666 ]
# [(tensor([-0.8193, -0.9995], grad_fn=<AddBackward0>),)]
# projection step=0, g=1.569e-02, x=[ 0.18015748 -1.1796188 ]
# projection step=1, g=1.755e-04, x=[ 0.1878541 -1.1702298]
# [(tensor([-0.7407, -0.9593], grad_fn=<AddBackward0>),)]
# projection step=0, g=-1.600e-02, x=[ 0.2185708 -1.1778512]
# projection step=1, g=2.041e-04, x=[ 0.21050043 -1.188303  ]
# [(tensor([-0.7621, -0.9956], grad_fn=<AddBackward0>),)]
# projection step=0, g=2.284e-02, x=[ 0.23344794 -1.2290255 ]
# projection step=1, g=3.872e-04, x=[ 0.24451923 -1.2145629 ]
# [(tensor([-0.6655, -0.9430], grad_fn=<AddBackward0>),)]
# projection step=0, g=-1.691e-02, x=[ 0.27750704 -1.2204673 ]
# projection step=1, g=2.441e-04, x=[ 0.26906005 -1.2324369 ]
# [(tensor([-0.7422, -0.9930], grad_fn=<AddBackward0>),)]
# projection step=0, g=2.448e-02, x=[ 0.25079536 -1.2437973 ]
# projection step=1, g=4.517e-04, x=[ 0.26261503 -1.2279837 ]
# [(tensor([-0.7157, -0.9810], grad_fn=<AddBackward0>),)]
# projection step=0, g=1.632e-02, x=[ 0.26525372 -1.2462113 ]
# projection step=1, g=2.077e-04, x=[ 0.27317455 -1.2353549 ]
# [(tensor([-0.6889, -0.9566], grad_fn=<AddBackward0>),)]
# projection step=0, g=-6.572e-03, x=[ 0.26775172 -1.2243944 ]
# projection step=1, g=3.552e-05, x=[ 0.26449406 -1.2289182 ]
# [(tensor([-0.6621, -0.9433], grad_fn=<AddBackward0>),)]
# projection step=0, g=-1.556e-02, x=[ 0.28122413 -1.2245167 ]
# projection step=1, g=2.068e-04, x=[ 0.27346954 -1.2355652 ]
# [(tensor([-0.8296, -1.0711], grad_fn=<AddBackward0>),)]
# projection step=0, g=1.028e-01, x=[ 0.2415165 -1.3126607]
# projection step=1, g=6.750e-03, x=[ 0.28799585 -1.2526505 ]
# projection step=2, g=3.850e-05, x=[ 0.29150763 -1.2481164 ]
# [(tensor([-0.6732, -0.9571], grad_fn=<AddBackward0>),)]
# projection step=0, g=-1.698e-03, x=[ 0.2838859 -1.2409717]
# projection step=1, g=2.384e-06, x=[ 0.28305113 -1.2421584 ]
# [(tensor([-0.8242, -1.0628], grad_fn=<AddBackward0>),)]
# projection step=0, g=9.317e-02, x=[ 0.23853675 -1.3012922 ]
# projection step=1, g=5.625e-03, x=[ 0.28099403 -1.2465473 ]
# projection step=2, g=2.652e-05, x=[ 0.2839094 -1.2427882]
# [(tensor([-0.6553, -0.9310], grad_fn=<AddBackward0>),)]
# projection step=0, g=-2.855e-02, x=[ 0.2757701 -1.206813 ]
# projection step=1, g=7.148e-04, x=[ 0.26133487 -1.2273233 ]
# [(tensor([-0.7907, -1.0166], grad_fn=<AddBackward0>),)]
# projection step=0, g=4.229e-02, x=[ 0.22590178 -1.2425365 ]
# projection step=1, g=1.265e-03, x=[ 0.24606039 -1.2166189 ]
# projection step=2, g=1.311e-06, x=[ 0.24670163 -1.2157944 ]
# [(tensor([-0.8794, -1.0579], grad_fn=<AddBackward0>),)]
# projection step=0, g=7.548e-02, x=[ 0.17850113 -1.2363737 ]
# projection step=1, g=3.600e-03, x=[ 0.2135751 -1.1941801]
# projection step=2, g=1.007e-05, x=[ 0.21542452 -1.1919553 ]
# [(tensor([-0.7609, -0.9662], grad_fn=<AddBackward0>),)]
# projection step=0, g=-1.211e-02, x=[ 0.20535709 -1.1715912 ]
# projection step=1, g=1.141e-04, x=[ 0.19926517 -1.1793272 ]
# [(tensor([-0.8899, -1.0362], grad_fn=<AddBackward0>),)]
# projection step=0, g=4.755e-02, x=[ 0.14632848 -1.182515  ]
# projection step=1, g=1.462e-03, x=[ 0.16900857 -1.1561054 ]
# projection step=2, g=1.490e-06, x=[ 0.16975166 -1.15524   ]
# [(tensor([-0.7024, -0.9231], grad_fn=<AddBackward0>),)]
# projection step=0, g=-4.960e-02, x=[ 0.22070079 -1.1437898 ]
# projection step=1, g=2.131e-03, x=[ 0.19480765 -1.1778189 ]
# projection step=2, g=3.338e-06, x=[ 0.19583191 -1.1764728 ]
# [(tensor([-0.7324, -0.9520], grad_fn=<AddBackward0>),)]
# projection step=0, g=-2.273e-02, x=[ 0.21957892 -1.1715865 ]
# projection step=1, g=4.188e-04, x=[ 0.20803824 -1.186587  ]
# [(tensor([-0.7287, -0.9530], grad_fn=<AddBackward0>),)]
# projection step=0, g=-2.078e-02, x=[ 0.22422382 -1.1771976 ]
# projection step=1, g=3.502e-04, x=[ 0.21370076 -1.1909584 ]
# [(tensor([-0.7354, -0.9790], grad_fn=<AddBackward0>),)]
# projection step=0, g=8.852e-03, x=[ 0.24360274 -1.2225623 ]
# projection step=1, g=6.068e-05, x=[ 0.24794492 -1.2167817 ]
# [(tensor([-0.8460, -1.0394], grad_fn=<AddBackward0>),)]
# projection step=0, g=5.892e-02, x=[ 0.19346523 -1.2328922 ]
# projection step=1, g=2.298e-03, x=[ 0.22121647 -1.1987944 ]
# projection step=2, g=4.053e-06, x=[ 0.22239026 -1.1973522 ]
# [(tensor([-0.7295, -0.9602], grad_fn=<AddBackward0>),)]
# projection step=0, g=-1.242e-02, x=[ 0.23066019 -1.1908432 ]
# projection step=1, g=1.236e-04, x=[ 0.22442818 -1.1990457 ]
# [(tensor([-0.7780, -0.9750], grad_fn=<AddBackward0>),)]
# projection step=0, g=-5.253e-03, x=[ 0.19705692 -1.1720759 ]
# projection step=1, g=2.092e-05, x=[ 0.19443022 -1.175368  ]
# [(tensor([-0.7941, -0.9929], grad_fn=<AddBackward0>),)]
# projection step=0, g=1.274e-02, x=[ 0.19881834 -1.1917675 ]
# projection step=1, g=1.187e-04, x=[ 0.20507589 -1.1839433 ]
# [(tensor([-0.7993, -0.9888], grad_fn=<AddBackward0>),)]
# projection step=0, g=6.848e-03, x=[ 0.18949075 -1.1783231 ]
# projection step=1, g=3.433e-05, x=[ 0.19287659 -1.1741346 ]
# [(tensor([-0.8110, -1.0157], grad_fn=<AddBackward0>),)]
# projection step=0, g=3.675e-02, x=[ 0.20468524 -1.2203616 ]
# projection step=1, g=9.450e-04, x=[ 0.22232665 -1.1982677 ]
# [(tensor([-0.7382, -0.9636], grad_fn=<AddBackward0>),)]
# projection step=0, g=-1.038e-02, x=[ 0.22538483 -1.1889466 ]
# projection step=1, g=8.523e-05, x=[ 0.22018668 -1.1957319 ]
# [(tensor([-0.7695, -0.9828], grad_fn=<AddBackward0>),)]
# projection step=0, g=5.721e-03, x=[ 0.21331215 -1.1961343 ]
# projection step=1, g=2.468e-05, x=[ 0.21613754 -1.1925257 ]
# [(tensor([-0.7803, -0.9800], grad_fn=<AddBackward0>),)]
# projection step=0, g=9.394e-05, x=[ 0.19964415 -1.1796085 ]
# [(tensor([-0.8329, -1.0233], grad_fn=<AddBackward0>),)]
# projection step=0, g=4.174e-02, x=[ 0.19044504 -1.2137735 ]
# projection step=1, g=1.189e-03, x=[ 0.21041207 -1.1892408 ]
# projection step=2, g=1.073e-06, x=[ 0.21101554 -1.1884993 ]
# [(tensor([-0.7742, -1.0033], grad_fn=<AddBackward0>),)]
# projection step=0, g=2.950e-02, x=[ 0.22904879 -1.2323117 ]
# projection step=1, g=6.341e-04, x=[ 0.2432705 -1.2138826]
# [(tensor([-0.7838, -0.9988], grad_fn=<AddBackward0>),)]
# projection step=0, g=2.196e-02, x=[ 0.21502273 -1.2138672 ]
# projection step=1, g=3.520e-04, x=[ 0.22570135 -1.2002591 ]
# [(tensor([-0.7003, -0.9369], grad_fn=<AddBackward0>),)]
# projection step=0, g=-3.312e-02, x=[ 0.23664124 -1.1735338 ]
# projection step=1, g=9.288e-04, x=[ 0.21969101 -1.1962122 ]
# [(tensor([-0.8101, -1.0154], grad_fn=<AddBackward0>),)]
# projection step=0, g=3.664e-02, x=[ 0.20530039 -1.2207437 ]
# projection step=1, g=9.402e-04, x=[ 0.22288957 -1.1986972 ]
# [(tensor([-0.6930, -0.9412], grad_fn=<AddBackward0>),)]
# projection step=0, g=-2.628e-02, x=[ 0.24816054 -1.1893599 ]
# projection step=1, g=5.831e-04, x=[ 0.23482892 -1.2074653 ]
# [(tensor([-0.7565, -0.9950], grad_fn=<AddBackward0>),)]
# projection step=0, g=2.341e-02, x=[ 0.23846176 -1.2334319 ]
# projection step=1, g=4.088e-04, x=[ 0.24980009 -1.2185196 ]
# [(tensor([-0.6333, -0.8841], grad_fn=<AddBackward0>),)]
# projection step=0, g=-7.776e-02, x=[ 0.25075424 -1.1348333 ]
# projection step=1, g=5.844e-03, x=[ 0.2091126 -1.1929623]
# projection step=2, g=2.491e-05, x=[ 0.2118332 -1.1891645]
# [(tensor([-0.9243, -1.0919], grad_fn=<AddBackward0>),)]
# projection step=0, g=1.102e-01, x=[ 0.16768599 -1.2596242 ]
# projection step=1, g=7.135e-03, x=[ 0.21746421 -1.2008148 ]
# projection step=2, g=3.940e-05, x=[ 0.22116539 -1.1964421 ]
# [(tensor([-0.6986, -0.9503], grad_fn=<AddBackward0>),)]
# projection step=0, g=-1.683e-02, x=[ 0.25169948 -1.2019572 ]
# projection step=1, g=2.347e-04, x=[ 0.24324794 -1.213454  ]
# [(tensor([-0.6039, -0.8885], grad_fn=<AddBackward0>),)]
# projection step=0, g=-6.476e-02, x=[ 0.28460148 -1.1731309 ]
# projection step=1, g=4.080e-03, x=[ 0.25071725 -1.222983  ]
# projection step=2, g=1.287e-05, x=[ 0.2526131 -1.2201937]
# [(tensor([-0.8285, -1.0542], grad_fn=<AddBackward0>),)]
# projection step=0, g=8.112e-02, x=[ 0.22567661 -1.2798618 ]
# projection step=1, g=4.307e-03, x=[ 0.26306096 -1.2322944 ]
# projection step=2, g=1.520e-05, x=[ 0.2652819 -1.2294686]
# [(tensor([-0.7161, -0.9819], grad_fn=<AddBackward0>),)]
# projection step=0, g=1.735e-02, x=[ 0.26574457 -1.2476201 ]
# projection step=1, g=2.344e-04, x=[ 0.27415717 -1.2360858 ]
# [(tensor([-0.6224, -0.9125], grad_fn=<AddBackward0>),)]
# projection step=0, g=-4.154e-02, x=[ 0.2901664 -1.2026982]
# projection step=1, g=1.590e-03, x=[ 0.26897398 -1.2337712 ]
# projection step=2, g=1.907e-06, x=[ 0.26972756 -1.2326663 ]
# [(tensor([-0.7824, -0.9878], grad_fn=<AddBackward0>),)]
# projection step=0, g=8.950e-03, x=[ 0.20536153 -1.1931498 ]
# projection step=1, g=5.949e-05, x=[ 0.20977129 -1.1875826 ]
# [(tensor([-0.7221, -0.9670], grad_fn=<AddBackward0>),)]
# projection step=0, g=-2.506e-03, x=[ 0.24489033 -1.2118529 ]
# projection step=1, g=4.947e-06, x=[ 0.24364786 -1.2135167 ]
# [(tensor([-0.7634, -0.9862], grad_fn=<AddBackward0>),)]
# projection step=0, g=1.107e-02, x=[ 0.2227878 -1.208941 ]
# projection step=1, g=9.221e-05, x=[ 0.22821955 -1.201924  ]
# [(tensor([-0.7999, -1.0183], grad_fn=<AddBackward0>),)]
# projection step=0, g=4.230e-02, x=[ 0.21838263 -1.2366734 ]
# projection step=1, g=1.256e-03, x=[ 0.23856366 -1.2109827 ]
# projection step=2, g=1.192e-06, x=[ 0.2392005 -1.2101719]
# [(tensor([-0.7221, -0.9709], grad_fn=<AddBackward0>),)]
# projection step=0, g=2.287e-03, x=[ 0.24884036 -1.2197429 ]
# projection step=1, g=4.053e-06, x=[ 0.24996816 -1.2182264 ]
# [(tensor([-0.7295, -0.9750], grad_fn=<AddBackward0>),)]
# projection step=0, g=5.483e-03, x=[ 0.2455073 -1.2205417]
# projection step=1, g=2.348e-05, x=[ 0.2482047 -1.2169366]
# [(tensor([-0.6891, -0.9221], grad_fn=<AddBackward0>),)]
# projection step=0, g=-4.769e-02, x=[ 0.2330241 -1.1551564]
# projection step=1, g=1.988e-03, x=[ 0.20822723 -1.1883384 ]
# projection step=2, g=2.980e-06, x=[ 0.20918155 -1.1870614 ]
# [(tensor([-0.7961, -1.0098], grad_fn=<AddBackward0>),)]
# projection step=0, g=3.272e-02, x=[ 0.21372232 -1.2235589 ]
# projection step=1, g=7.628e-04, x=[ 0.22947715 -1.2035745 ]
# [(tensor([-0.6937, -0.9409], grad_fn=<AddBackward0>),)]
# projection step=0, g=-2.677e-02, x=[ 0.24723125 -1.1881518 ]
# projection step=1, g=6.051e-04, x=[ 0.2336408 -1.2065859]
# [(tensor([-0.7181, -0.9619], grad_fn=<AddBackward0>),)]
# projection step=0, g=-7.695e-03, x=[ 0.24375738 -1.2056264 ]
# projection step=1, g=4.756e-05, x=[ 0.23992223 -1.2107633 ]
# [(tensor([-0.7420, -0.9853], grad_fn=<AddBackward0>),)]
# projection step=0, g=1.505e-02, x=[ 0.24333227 -1.2286706 ]
# projection step=1, g=1.729e-04, x=[ 0.25067258 -1.2189231 ]
# step=200, loss=-0.970841109752655
# [(tensor([-0.7426, -1.0012], grad_fn=<AddBackward0>),)]
# projection step=0, g=3.468e-02, x=[ 0.25864166 -1.2598708 ]
# projection step=1, g=8.946e-04, x=[ 0.27521363 -1.2375268 ]
# [(tensor([-0.8561, -1.0769], grad_fn=<AddBackward0>),)]
# projection step=0, g=1.042e-01, x=[ 0.22071616 -1.2975736 ]
# projection step=1, g=6.770e-03, x=[ 0.2678382 -1.2383033]
# projection step=2, g=3.779e-05, x=[ 0.2713582 -1.2338759]
# [(tensor([-0.6713, -0.9589], grad_fn=<AddBackward0>),)]
# projection step=0, g=1.058e-03, x=[ 0.28754377 -1.2464149 ]
# projection step=1, g=9.537e-07, x=[ 0.28806198 -1.2456747 ]
# [(tensor([-0.6555, -0.9686], grad_fn=<AddBackward0>),)]
# projection step=0, g=1.814e-02, x=[ 0.31310436 -1.2817367 ]
# projection step=1, g=2.698e-04, x=[ 0.32179776 -1.2688911 ]
# [(tensor([-0.6488, -0.9728], grad_fn=<AddBackward0>),)]
# projection step=0, g=2.571e-02, x=[ 0.3240405 -1.2968756]
# projection step=1, g=5.391e-04, x=[ 0.33623743 -1.2785869 ]
# [(tensor([-0.6782, -0.9864], grad_fn=<AddBackward0>),)]
# projection step=0, g=3.404e-02, x=[ 0.30822405 -1.2946718 ]
# projection step=1, g=9.115e-04, x=[ 0.32433435 -1.27124   ]
# [(tensor([-0.6837, -1.0049], grad_fn=<AddBackward0>),)]
# projection step=0, g=5.650e-02, x=[ 0.32117462 -1.3260826 ]
# projection step=1, g=2.427e-03, x=[ 0.34732217 -1.2876526 ]
# projection step=2, g=5.305e-06, x=[ 0.348551  -1.2858465]
# [(tensor([-0.6063, -0.9170], grad_fn=<AddBackward0>),)]
# projection step=0, g=-3.134e-02, x=[ 0.31062844 -1.2275931 ]
# projection step=1, g=9.041e-04, x=[ 0.29490247 -1.2513756 ]
# [(tensor([-0.7611, -1.0143], grad_fn=<AddBackward0>),)]
# projection step=0, g=4.648e-02, x=[ 0.25322258 -1.2675383 ]
# projection step=1, g=1.559e-03, x=[ 0.27522054 -1.2382214 ]
# projection step=2, g=1.967e-06, x=[ 0.2760112 -1.2371677]
# [(tensor([-0.7418, -1.0003], grad_fn=<AddBackward0>),)]
# projection step=0, g=3.375e-02, x=[ 0.25854632 -1.2588698 ]
# projection step=1, g=8.488e-04, x=[ 0.2746871 -1.2371031]
# [(tensor([-0.7666, -1.0260], grad_fn=<AddBackward0>),)]
# projection step=0, g=5.996e-02, x=[ 0.25941876 -1.2853944 ]
# projection step=1, g=2.540e-03, x=[ 0.2874418 -1.2478878]
# projection step=2, g=5.484e-06, x=[ 0.28873855 -1.2461523 ]
# [(tensor([-0.6226, -0.9254], grad_fn=<AddBackward0>),)]
# projection step=0, g=-2.601e-02, x=[ 0.30278257 -1.2281456 ]
# projection step=1, g=6.086e-04, x=[ 0.28976294 -1.2474971 ]
# [(tensor([-0.6608, -0.9517], grad_fn=<AddBackward0>),)]
# projection step=0, g=-4.851e-03, x=[ 0.29086083 -1.242543  ]
# projection step=1, g=1.991e-05, x=[ 0.28847304 -1.2459818 ]
# [(tensor([-0.6595, -0.9683], grad_fn=<AddBackward0>),)]
# projection step=0, g=1.645e-02, x=[ 0.30881152 -1.2770764 ]
# projection step=1, g=2.217e-04, x=[ 0.31671613 -1.2654701 ]
# [(tensor([-0.7868, -1.0224], grad_fn=<AddBackward0>),)]
# projection step=0, g=5.042e-02, x=[ 0.23558563 -1.2580031 ]
# projection step=1, g=1.786e-03, x=[ 0.25942028 -1.2270321 ]
# projection step=2, g=2.682e-06, x=[ 0.2603288 -1.2258515]
# [(tensor([-0.7164, -0.9887], grad_fn=<AddBackward0>),)]
# projection step=0, g=2.585e-02, x=[ 0.27227417 -1.2609916 ]
# projection step=1, g=5.141e-04, x=[ 0.28469554 -1.2438496 ]
# [(tensor([-0.7028, -0.9812], grad_fn=<AddBackward0>),)]
# projection step=0, g=2.015e-02, x=[ 0.27844733 -1.259652  ]
# projection step=1, g=3.185e-04, x=[ 0.28816772 -1.2460802 ]
# [(tensor([-0.6170, -0.9193], grad_fn=<AddBackward0>),)]
# projection step=0, g=-3.172e-02, x=[ 0.30235785 -1.2216676 ]
# projection step=1, g=9.179e-04, x=[ 0.28639016 -1.2454609 ]
# [(tensor([-0.6408, -0.9269], grad_fn=<AddBackward0>),)]
# projection step=0, g=-2.952e-02, x=[ 0.28609917 -1.2129825 ]
# projection step=1, g=7.750e-04, x=[ 0.27120277 -1.2345299 ]
# [(tensor([-0.6863, -0.9515], grad_fn=<AddBackward0>),)]
# projection step=0, g=-1.210e-02, x=[ 0.2652733 -1.2168158]
# projection step=1, g=1.220e-04, x=[ 0.259241  -1.2251799]
# [(tensor([-0.7704, -0.9955], grad_fn=<AddBackward0>),)]
# projection step=0, g=2.079e-02, x=[ 0.2250788 -1.2205331]
# projection step=1, g=3.198e-04, x=[ 0.23518975 -1.2074682 ]
# [(tensor([-0.7521, -0.9759], grad_fn=<AddBackward0>),)]
# projection step=0, g=1.202e-03, x=[ 0.22381324 -1.1996782 ]
# projection step=1, g=1.073e-06, x=[ 0.22440897 -1.1989051 ]
# [(tensor([-0.7590, -0.9946], grad_fn=<AddBackward0>),)]
# projection step=0, g=2.236e-02, x=[ 0.23562193 -1.2302066 ]
# projection step=1, g=3.725e-04, x=[ 0.24646321 -1.2159996 ]
# [(tensor([-0.7618, -0.9963], grad_fn=<AddBackward0>),)]
# projection step=0, g=2.383e-02, x=[ 0.23451531 -1.2308404 ]
# projection step=1, g=4.213e-04, x=[ 0.24605642 -1.2157465 ]
# [(tensor([-0.7908, -1.0118], grad_fn=<AddBackward0>),)]
# projection step=0, g=3.626e-02, x=[ 0.22094877 -1.2327324 ]
# projection step=1, g=9.367e-04, x=[ 0.23833823 -1.2104845 ]
# [(tensor([-0.8076, -1.0155], grad_fn=<AddBackward0>),)]
# projection step=0, g=3.727e-02, x=[ 0.20792767 -1.2234597 ]
# projection step=1, g=9.744e-04, x=[ 0.22580622 -1.2009782 ]
# [(tensor([-0.6690, -0.9324], grad_fn=<AddBackward0>),)]
# projection step=0, g=-3.064e-02, x=[ 0.26337326 -1.1957616 ]
# projection step=1, g=8.154e-04, x=[ 0.24780612 -1.217457  ]
# [(tensor([-0.7078, -0.9571], grad_fn=<AddBackward0>),)]
# projection step=0, g=-1.096e-02, x=[ 0.24921344 -1.2062743 ]
# projection step=1, g=9.793e-05, x=[ 0.24373671 -1.2136792 ]
# [(tensor([-0.8422, -1.0257], grad_fn=<AddBackward0>),)]
# projection step=0, g=4.288e-02, x=[ 0.1835451 -1.2092491]
# projection step=1, g=1.244e-03, x=[ 0.20404741 -1.1842785 ]
# projection step=2, g=1.192e-06, x=[ 0.20467894 -1.1835093 ]
# [(tensor([-0.7758, -1.0001], grad_fn=<AddBackward0>),)]
# projection step=0, g=2.523e-02, x=[ 0.22423923 -1.2243258 ]
# projection step=1, g=4.658e-04, x=[ 0.23645635 -1.2085776 ]
# [(tensor([-0.6570, -0.9515], grad_fn=<AddBackward0>),)]
# projection step=0, g=-3.924e-03, x=[ 0.29449293 -1.2460316 ]
# projection step=1, g=1.305e-05, x=[ 0.29256472 -1.2488241 ]
# [(tensor([-0.7200, -1.0226], grad_fn=<AddBackward0>),)]
# projection step=0, g=6.868e-02, x=[ 0.3025938 -1.3252312]
# projection step=1, g=3.426e-03, x=[ 0.3342058 -1.2803345]
# projection step=2, g=1.055e-05, x=[ 0.33595788 -1.2778461 ]
# [(tensor([-0.6712, -0.9844], grad_fn=<AddBackward0>),)]
# projection step=0, g=3.364e-02, x=[ 0.31327492 -1.2977219 ]
# projection step=1, g=8.960e-04, x=[ 0.32917875 -1.2743948 ]
# [(tensor([-0.6669, -0.9691], grad_fn=<AddBackward0>),)]
# projection step=0, g=1.528e-02, x=[ 0.3022574 -1.2713823]
# projection step=1, g=1.903e-04, x=[ 0.309621  -1.2606812]
# [(tensor([-0.6567, -0.9557], grad_fn=<AddBackward0>),)]
# projection step=0, g=1.389e-03, x=[ 0.29900873 -1.2547135 ]
# projection step=1, g=1.669e-06, x=[ 0.2996871 -1.2537264]
# [(tensor([-0.6957, -0.9852], grad_fn=<AddBackward0>),)]
# projection step=0, g=2.726e-02, x=[ 0.28954706 -1.2747777 ]
# projection step=1, g=5.811e-04, x=[ 0.30258328 -1.2563157 ]
# [(tensor([-0.7658, -1.0326], grad_fn=<AddBackward0>),)]
# projection step=0, g=6.867e-02, x=[ 0.266731 -1.299295]
# projection step=1, g=3.298e-03, x=[ 0.29855025 -1.2563934 ]
# projection step=2, g=9.298e-06, x=[ 0.30024084 -1.254114  ]
# [(tensor([-0.6962, -0.9760], grad_fn=<AddBackward0>),)]
# projection step=0, g=1.542e-02, x=[ 0.2797862 -1.255775 ]
# projection step=1, g=1.888e-04, x=[ 0.28725424 -1.2453057 ]
# [(tensor([-0.8069, -1.0586], grad_fn=<AddBackward0>),)]
# projection step=0, g=9.203e-02, x=[ 0.25172246 -1.3103554 ]
# projection step=1, g=5.574e-03, x=[ 0.29363623 -1.2553663 ]
# projection step=2, g=2.640e-05, x=[ 0.29652432 -1.2515773 ]
# [(tensor([-0.7333, -1.0033], grad_fn=<AddBackward0>),)]
# projection step=0, g=3.972e-02, x=[ 0.2699649 -1.2732409]
# projection step=1, g=1.176e-03, x=[ 0.28882676 -1.2474352 ]
# projection step=2, g=1.192e-06, x=[ 0.28942007 -1.2466235 ]
# [(tensor([-0.6301, -0.9540], grad_fn=<AddBackward0>),)]
# projection step=0, g=7.454e-03, x=[ 0.32383573 -1.2777954 ]
# projection step=1, g=4.733e-05, x=[ 0.32742932 -1.2723551 ]
# [(tensor([-0.5572, -0.9193], grad_fn=<AddBackward0>),)]
# projection step=0, g=-1.189e-02, x=[ 0.36207724 -1.2813787 ]
# projection step=1, g=1.319e-04, x=[ 0.35634285 -1.2908393 ]
# [(tensor([-0.6467, -0.9600], grad_fn=<AddBackward0>),)]
# projection step=0, g=9.887e-03, x=[ 0.31327456 -1.2732916 ]
# projection step=1, g=8.160e-05, x=[ 0.31804672 -1.2662078 ]
# [(tensor([-0.7947, -1.0660], grad_fn=<AddBackward0>),)]
# projection step=0, g=1.050e-01, x=[ 0.27133405 -1.3373716 ]
# projection step=1, g=7.224e-03, x=[ 0.31854418 -1.2740426 ]
# projection step=2, g=4.601e-05, x=[ 0.32230917 -1.2689922 ]
# [(tensor([-0.6810, -0.9841], grad_fn=<AddBackward0>),)]
# projection step=0, g=3.016e-02, x=[ 0.30309308 -1.2871947 ]
# projection step=1, g=7.176e-04, x=[ 0.31743416 -1.2664709 ]
# [(tensor([-0.5867, -0.9216], grad_fn=<AddBackward0>),)]
# projection step=0, g=-1.921e-02, x=[ 0.33494106 -1.256566  ]
# projection step=1, g=3.392e-04, x=[ 0.32549834 -1.2713996 ]
# [(tensor([-0.6191, -0.9566], grad_fn=<AddBackward0>),)]
# projection step=0, g=1.456e-02, x=[ 0.33755237 -1.2941979 ]
# projection step=1, g=1.801e-04, x=[ 0.34449267 -1.2834735 ]
# [(tensor([-0.7146, -1.0105], grad_fn=<AddBackward0>),)]
# projection step=0, g=5.434e-02, x=[ 0.29589242 -1.306399  ]
# projection step=1, g=2.194e-03, x=[ 0.32124218 -1.2705529 ]
# projection step=2, g=4.232e-06, x=[ 0.32235545 -1.2689786 ]
# [(tensor([-0.7172, -1.0042], grad_fn=<AddBackward0>),)]
# projection step=0, g=4.536e-02, x=[ 0.28694832 -1.2911268 ]
# projection step=1, g=1.543e-03, x=[ 0.30831125 -1.2612171 ]
# projection step=2, g=2.027e-06, x=[ 0.3090909 -1.2601255]
# [(tensor([-0.6781, -0.9509], grad_fn=<AddBackward0>),)]
# projection step=0, g=-1.067e-02, x=[ 0.27277493 -1.2236946 ]
# projection step=1, g=9.531e-05, x=[ 0.26746917 -1.2311345 ]
# [(tensor([-0.8099, -1.0473], grad_fn=<AddBackward0>),)]
# projection step=0, g=7.662e-02, x=[ 0.2374486 -1.2847577]
# projection step=1, g=3.922e-03, x=[ 0.272851  -1.2389755]
# projection step=2, g=1.276e-05, x=[ 0.27486995 -1.2363646 ]
# ...
# projection step=1, g=5.066e-04, x=[ 0.05117561 -1.0503724 ]
# [(tensor([-0.9532, -0.9974], grad_fn=<AddBackward0>),)]
# projection step=0, g=-1.635e-03, x=[ 0.04423139 -1.041615  ]
# projection step=1, g=1.729e-06, x=[ 0.0434127 -1.0424716]
# [(tensor([-0.9843, -1.0113], grad_fn=<AddBackward0>),)]
# projection step=0, g=1.175e-02, x=[ 0.02698532 -1.038308  ]
# projection step=1, g=8.613e-05, x=[ 0.03279288 -1.0323412 ]
# [(tensor([-0.9004, -0.9739], grad_fn=<AddBackward0>),)]
# projection step=0, g=-2.301e-02, x=[ 0.07355876 -1.0475056 ]
# projection step=1, g=3.698e-04, x=[ 0.06178321 -1.0602432 ]
# [(tensor([-1.0892, -1.1007], grad_fn=<AddBackward0>),)]
# projection step=0, g=1.059e-01, x=[ 0.01149838 -1.1122402 ]
# projection step=1, g=5.831e-03, x=[ 0.05959165 -1.0636393 ]
# projection step=2, g=2.235e-05, x=[ 0.0625682 -1.0606313]
# [(tensor([-0.8915, -0.9911], grad_fn=<AddBackward0>),)]
# projection step=0, g=-3.912e-03, x=[ 0.09959518 -1.0906837 ]
# projection step=1, g=1.049e-05, x=[ 0.09763252 -1.0928656 ]
# [(tensor([-0.7707, -0.9187], grad_fn=<AddBackward0>),)]
# projection step=0, g=-6.703e-02, x=[ 0.14802197 -1.0667286 ]
# projection step=1, g=3.747e-03, x=[ 0.11209515 -1.1095557 ]
# projection step=2, g=9.418e-06, x=[ 0.11390121 -1.1074028 ]
# [(tensor([-0.7378, -0.9030], grad_fn=<AddBackward0>),)]
# projection step=0, g=-7.864e-02, x=[ 0.16519842 -1.0682137 ]
# projection step=1, g=5.412e-03, x=[ 0.12253121 -1.1204342 ]
# projection step=2, g=1.979e-05, x=[ 0.12511247 -1.117275  ]
# [(tensor([-0.8082, -0.9586], grad_fn=<AddBackward0>),)]
# projection step=0, g=-2.927e-02, x=[ 0.15034384 -1.1089143 ]
# projection step=1, g=6.542e-04, x=[ 0.13529596 -1.1267613 ]
# [(tensor([-0.9053, -1.0001], grad_fn=<AddBackward0>),)]
# projection step=0, g=4.543e-03, x=[ 0.09477485 -1.0948265 ]
# projection step=1, g=1.377e-05, x=[ 0.0970349 -1.0923297]
# [(tensor([-1.0572, -1.0840], grad_fn=<AddBackward0>),)]
# projection step=0, g=8.793e-02, x=[ 0.02685461 -1.11089   ]
# projection step=1, g=4.193e-03, x=[ 0.06739725 -1.0693176 ]
# projection step=2, g=1.168e-05, x=[ 0.06953466 -1.0671259 ]
# [(tensor([-0.8918, -0.9811], grad_fn=<AddBackward0>),)]
# projection step=0, g=-1.476e-02, x=[ 0.08927053 -1.0703446 ]
# projection step=1, g=1.518e-04, x=[ 0.08178111 -1.0785837 ]
# [(tensor([-1.0403, -1.0915], grad_fn=<AddBackward0>),)]
# projection step=0, g=9.696e-02, x=[ 0.05113606 -1.1426067 ]
# projection step=1, g=5.117e-03, x=[ 0.09550285 -1.0960592 ]
# projection step=2, g=1.770e-05, x=[ 0.09812049 -1.0933129 ]
# [(tensor([-0.9854, -1.0420], grad_fn=<AddBackward0>),)]
# projection step=0, g=4.452e-02, x=[ 0.05662326 -1.0986551 ]
# projection step=1, g=1.190e-03, x=[ 0.07795125 -1.0761015 ]
# projection step=2, g=8.941e-07, x=[ 0.07855366 -1.0754645 ]
# [(tensor([-0.9258, -0.9990], grad_fn=<AddBackward0>),)]
# projection step=0, g=1.653e-03, x=[ 0.07318679 -1.0721616 ]
# projection step=1, g=1.848e-06, x=[ 0.07401197 -1.0712712 ]
# [(tensor([-0.9970, -1.0427], grad_fn=<AddBackward0>),)]
# projection step=0, g=4.462e-02, x=[ 0.045655  -1.0883214]
# projection step=1, g=1.185e-03, x=[ 0.06703007 -1.0659676 ]
# projection step=2, g=8.345e-07, x=[ 0.06762938 -1.0653408 ]
# [(tensor([-0.9099, -1.0108], grad_fn=<AddBackward0>),)]
# projection step=0, g=1.594e-02, x=[ 0.10093441 -1.1117201 ]
# projection step=1, g=1.677e-04, x=[ 0.10877483 -1.1030099 ]
# [(tensor([-0.8910, -0.9789], grad_fn=<AddBackward0>),)]
# projection step=0, g=-1.703e-02, x=[ 0.08788594 -1.0667686 ]
# projection step=1, g=2.027e-04, x=[ 0.07922441 -1.0762845 ]
# [(tensor([-0.9847, -1.0511], grad_fn=<AddBackward0>),)]
# projection step=0, g=5.464e-02, x=[ 0.06640361 -1.1175308 ]
# projection step=1, g=1.774e-03, x=[ 0.092339  -1.0898465]
# projection step=2, g=2.146e-06, x=[ 0.09323945 -1.0888853 ]
# [(tensor([-0.8266, -0.9526], grad_fn=<AddBackward0>),)]
# projection step=0, g=-3.829e-02, x=[ 0.12600338 -1.078652  ]
# projection step=1, g=1.115e-03, x=[ 0.10610637 -1.1015819 ]
# projection step=2, g=8.941e-07, x=[ 0.10665387 -1.100951  ]
# [(tensor([-0.9520, -1.0704], grad_fn=<AddBackward0>),)]
# projection step=0, g=7.984e-02, x=[ 0.11832321 -1.1886916 ]
# projection step=1, g=3.782e-03, x=[ 0.1553664 -1.1470445]
# projection step=2, g=1.043e-05, x=[ 0.1573047 -1.1448654]
# [(tensor([-0.9363, -1.0522], grad_fn=<AddBackward0>),)]
# projection step=0, g=6.029e-02, x=[ 0.11593974 -1.1681468 ]
# projection step=1, g=2.231e-03, x=[ 0.14439535 -1.1361675 ]
# projection step=2, g=3.576e-06, x=[ 0.1455325 -1.1348896]
# [(tensor([-0.8217, -0.9941], grad_fn=<AddBackward0>),)]
# projection step=0, g=8.997e-03, x=[ 0.17244065 -1.1665523 ]
# projection step=1, g=5.800e-05, x=[ 0.17688486 -1.1611754 ]
# [(tensor([-0.8879, -1.0552], grad_fn=<AddBackward0>),)]
# projection step=0, g=7.078e-02, x=[ 0.16737124 -1.2226152 ]
# projection step=1, g=3.160e-03, x=[ 0.20041287 -1.183345  ]
# projection step=2, g=7.629e-06, x=[ 0.20203298 -1.1814195 ]
# [(tensor([-0.9401, -1.0967], grad_fn=<AddBackward0>),)]
# projection step=0, g=1.137e-01, x=[ 0.1566303 -1.2533716]
# projection step=1, g=7.469e-03, x=[ 0.20785052 -1.1936177 ]
# projection step=2, g=4.274e-05, x=[ 0.21172485 -1.1890979 ]
# [(tensor([-0.8293, -0.9996], grad_fn=<AddBackward0>),)]
# projection step=0, g=1.411e-02, x=[ 0.17034125 -1.1699446 ]
# projection step=1, g=1.411e-04, x=[ 0.17727843 -1.1615825 ]
# [(tensor([-0.9062, -1.0421], grad_fn=<AddBackward0>),)]
# projection step=0, g=5.224e-02, x=[ 0.13587487 -1.177992  ]
# projection step=1, g=1.732e-03, x=[ 0.16069424 -1.1494514 ]
# projection step=2, g=2.265e-06, x=[ 0.16157545 -1.1484381 ]
# [(tensor([-0.7457, -0.9241], grad_fn=<AddBackward0>),)]
# projection step=0, g=-5.715e-02, x=[ 0.17837192 -1.1024258 ]
# projection step=1, g=2.748e-03, x=[ 0.14814416 -1.1398842 ]
# projection step=2, g=5.186e-06, x=[ 0.14946985 -1.1382414 ]
# [(tensor([-0.9193, -1.0368], grad_fn=<AddBackward0>),)]
# projection step=0, g=4.444e-02, x=[ 0.11758056 -1.1544282 ]
# projection step=1, g=1.251e-03, x=[ 0.13885622 -1.1304313 ]
# projection step=2, g=1.132e-06, x=[ 0.13949093 -1.1297154 ]
# [(tensor([-0.7195, -0.8705], grad_fn=<AddBackward0>),)]
# projection step=0, g=-1.097e-01, x=[ 0.15096931 -1.0214841 ]
# projection step=1, g=1.127e-02, x=[ 0.08908305 -1.0963548 ]
# projection step=2, g=8.178e-05, x=[ 0.09435547 -1.0899762 ]
# [(tensor([-0.8702, -0.9721], grad_fn=<AddBackward0>),)]
# projection step=0, g=-2.228e-02, x=[ 0.10196447 -1.0740968 ]
# projection step=1, g=3.556e-04, x=[ 0.09057461 -1.0868213 ]
# [(tensor([-0.9232, -1.0061], grad_fn=<AddBackward0>),)]
# projection step=0, g=9.559e-03, x=[ 0.08293771 -1.089039  ]
# projection step=1, g=6.014e-05, x=[ 0.08767077 -1.0838807 ]
# [(tensor([-0.8684, -0.9626], grad_fn=<AddBackward0>),)]
# projection step=0, g=-3.228e-02, x=[ 0.09414712 -1.0567378 ]
# projection step=1, g=7.573e-04, x=[ 0.07746946 -1.0752234 ]
# [(tensor([-1.0305, -1.0728], grad_fn=<AddBackward0>),)]
# projection step=0, g=7.638e-02, x=[ 0.04235345 -1.1151818 ]
# projection step=1, g=3.268e-03, x=[ 0.07792084 -1.0781525 ]
# projection step=2, g=7.033e-06, x=[ 0.07958487 -1.0764201 ]
# [(tensor([-0.9554, -1.0371], grad_fn=<AddBackward0>),)]
# projection step=0, g=4.111e-02, x=[ 0.08169685 -1.1187776 ]
# projection step=1, g=1.043e-03, x=[ 0.10144819 -1.0973374 ]
# projection step=2, g=7.749e-07, x=[ 0.10197642 -1.096764  ]
# [(tensor([-0.9135, -1.0097], grad_fn=<AddBackward0>),)]
# projection step=0, g=1.434e-02, x=[ 0.0961389 -1.1058114]
# projection step=1, g=1.357e-04, x=[ 0.10320507 -1.0980016 ]
# [(tensor([-1.0045, -1.0574], grad_fn=<AddBackward0>),)]
# projection step=0, g=6.050e-02, x=[ 0.05294514 -1.1103946 ]
# projection step=1, g=2.128e-03, x=[ 0.08151461 -1.0803193 ]
# projection step=2, g=3.040e-06, x=[ 0.08259536 -1.0791816 ]
# [(tensor([-0.8534, -0.9654], grad_fn=<AddBackward0>),)]
# projection step=0, g=-2.777e-02, x=[ 0.11194905 -1.077314  ]
# projection step=1, g=5.645e-04, x=[ 0.09767503 -1.0934604 ]
# [(tensor([-0.8929, -0.9946], grad_fn=<AddBackward0>),)]
# projection step=0, g=-1.976e-04, x=[ 0.10167513 -1.0962942 ]
# [(tensor([-0.9004, -1.0093], grad_fn=<AddBackward0>),)]
# projection step=0, g=1.530e-02, x=[ 0.10890319 -1.1182281 ]
# projection step=1, g=1.559e-04, x=[ 0.11643255 -1.1097881 ]
# [(tensor([-0.8891, -0.9990], grad_fn=<AddBackward0>),)]
# projection step=0, g=4.991e-03, x=[ 0.10989813 -1.1088501 ]
# projection step=1, g=1.705e-05, x=[ 0.11237952 -1.106062  ]
# [(tensor([-0.9560, -1.0501], grad_fn=<AddBackward0>),)]
# projection step=0, g=5.581e-02, x=[ 0.0941169 -1.1442407]
# projection step=1, g=1.891e-03, x=[ 0.12057277 -1.1151804 ]
# projection step=2, g=2.384e-06, x=[ 0.12153438 -1.1141241 ]
# [(tensor([-0.9229, -1.0252], grad_fn=<AddBackward0>),)]
# projection step=0, g=3.070e-02, x=[ 0.10222174 -1.1273793 ]
# projection step=1, g=6.047e-04, x=[ 0.11711217 -1.1108396 ]
# [(tensor([-0.8697, -1.0000], grad_fn=<AddBackward0>),)]
# projection step=0, g=8.533e-03, x=[ 0.13032058 -1.1303614 ]
# projection step=1, g=5.013e-05, x=[ 0.13454548 -1.1255034 ]
# [(tensor([-0.8367, -0.9998], grad_fn=<AddBackward0>),)]
# projection step=0, g=1.307e-02, x=[ 0.16304103 -1.1628174 ]
# projection step=1, g=1.203e-04, x=[ 0.16947408 -1.1551307 ]
# [(tensor([-0.8799, -0.9962], grad_fn=<AddBackward0>),)]
# projection step=0, g=2.936e-03, x=[ 0.11627478 -1.1124439 ]
# projection step=1, g=5.960e-06, x=[ 0.11773736 -1.1107881 ]
# [(tensor([-0.9635, -1.0291], grad_fn=<AddBackward0>),)]
# projection step=0, g=3.166e-02, x=[ 0.06558446 -1.0946754 ]
# projection step=1, g=6.217e-04, x=[ 0.08093599 -1.0782789 ]
# [(tensor([-0.9298, -1.0270], grad_fn=<AddBackward0>),)]
# projection step=0, g=3.206e-02, x=[ 0.09713642 -1.1241109 ]
# projection step=1, g=6.546e-04, x=[ 0.11266678 -1.1069582 ]
# [(tensor([-0.8976, -1.0008], grad_fn=<AddBackward0>),)]
# projection step=0, g=6.108e-03, x=[ 0.10315827 -1.1039456 ]
# projection step=1, g=2.515e-05, x=[ 0.10619213 -1.100563  ]
# [(tensor([-0.9253, -1.0144], grad_fn=<AddBackward0>),)]
# projection step=0, g=1.850e-02, x=[ 0.08909543 -1.1035265 ]
# projection step=1, g=2.225e-04, x=[ 0.09817748 -1.09357   ]
# [(tensor([-0.8516, -0.9574], grad_fn=<AddBackward0>),)]
# projection step=0, g=-3.605e-02, x=[ 0.10584914 -1.0632966 ]
# projection step=1, g=9.633e-04, x=[ 0.087154  -1.0843154]
# [(tensor([-0.8746, -0.9967], grad_fn=<AddBackward0>),)]
# projection step=0, g=4.167e-03, x=[ 0.12212835 -1.1188319 ]
# projection step=1, g=1.198e-05, x=[ 0.12420081 -1.11647   ]
# [(tensor([-0.8421, -0.9693], grad_fn=<AddBackward0>),)]
# projection step=0, g=-2.211e-02, x=[ 0.12722446 -1.0965497 ]
# projection step=1, g=3.588e-04, x=[ 0.11593097 -1.1095494 ]
# [(tensor([-0.8446, -0.9790], grad_fn=<AddBackward0>),)]
# projection step=0, g=-1.170e-02, x=[ 0.13446547 -1.1135093 ]
# projection step=1, g=9.876e-05, x=[ 0.12855685 -1.1203586 ]
# [(tensor([-0.8657, -1.0047], grad_fn=<AddBackward0>),)]
# projection step=0, g=1.434e-02, x=[ 0.1389337 -1.1436093]
# projection step=1, g=1.411e-04, x=[ 0.14599095 -1.1354195 ]
# [(tensor([-0.8721, -1.0144], grad_fn=<AddBackward0>),)]
# projection step=0, g=2.461e-02, x=[ 0.14227466 -1.1566578 ]
# projection step=1, g=4.084e-04, x=[ 0.15426683 -1.1427093 ]
# [(tensor([-0.8073, -0.9623], grad_fn=<AddBackward0>),)]
# projection step=0, g=-2.496e-02, x=[ 0.15497135 -1.1172895 ]
# projection step=1, g=4.736e-04, x=[ 0.14219812 -1.1325146 ]
# [(tensor([-0.8677, -0.9864], grad_fn=<AddBackward0>),)]
# projection step=0, g=-6.460e-03, x=[ 0.11867639 -1.1050824 ]
# projection step=1, g=2.933e-05, x=[ 0.11542883 -1.1087741 ]
# [(tensor([-0.8914, -1.0123], grad_fn=<AddBackward0>),)]
# projection step=0, g=1.964e-02, x=[ 0.12082695 -1.1330931 ]
# projection step=1, g=2.575e-04, x=[ 0.13045059 -1.1221651 ]
# [(tensor([-0.9349, -1.0337], grad_fn=<AddBackward0>),)]
# projection step=0, g=3.916e-02, x=[ 0.09880857 -1.1325209 ]
# projection step=1, g=9.651e-04, x=[ 0.11765588 -1.1116817 ]
# [(tensor([-0.8116, -0.9589], grad_fn=<AddBackward0>),)]
# projection step=0, g=-2.942e-02, x=[ 0.1472683 -1.1061605]
# projection step=1, g=6.590e-04, x=[ 0.13213906 -1.1240349 ]
# [(tensor([-0.8412, -0.9830], grad_fn=<AddBackward0>),)]
# projection step=0, g=-6.755e-03, x=[ 0.14179958 -1.1248474 ]
# projection step=1, g=3.284e-05, x=[ 0.13840516 -1.128814  ]
# [(tensor([-0.8500, -1.0093], grad_fn=<AddBackward0>),)]
# projection step=0, g=2.202e-02, x=[ 0.15929098 -1.168582  ]
# projection step=1, g=3.343e-04, x=[ 0.17004108 -1.1558173 ]
# [(tensor([-0.8300, -1.0177], grad_fn=<AddBackward0>),)]
# projection step=0, g=3.542e-02, x=[ 0.1876325 -1.2052974]
# projection step=1, g=8.655e-04, x=[ 0.20468172 -1.1843941 ]
# [(tensor([-0.8746, -1.0430], grad_fn=<AddBackward0>),)]
# projection step=0, g=5.814e-02, x=[ 0.16841215 -1.2114445 ]
# projection step=1, g=2.187e-03, x=[ 0.195856  -1.1787162]
# projection step=2, g=3.576e-06, x=[ 0.19697227 -1.177385  ]
# [(tensor([-0.8930, -1.0515], grad_fn=<AddBackward0>),)]
# projection step=0, g=6.541e-02, x=[ 0.158528 -1.210043]
# projection step=1, g=2.704e-03, x=[ 0.18921882 -1.1739037 ]
# projection step=2, g=5.484e-06, x=[ 0.19060197 -1.172275  ]
# [(tensor([-0.7983, -0.9640], grad_fn=<AddBackward0>),)]
# projection step=0, g=-2.158e-02, x=[ 0.16570202 -1.1297514 ]
# projection step=1, g=3.549e-04, x=[ 0.15470797 -1.1430274 ]
# [(tensor([-0.9802, -1.0905], grad_fn=<AddBackward0>),)]
# projection step=0, g=1.007e-01, x=[ 0.1103153 -1.2008171]
# projection step=1, g=5.755e-03, x=[ 0.15621708 -1.1497493 ]
# projection step=2, g=2.402e-05, x=[ 0.15917951 -1.1464535 ]
# [(tensor([-0.8549, -0.9985], grad_fn=<AddBackward0>),)]
# projection step=0, g=8.828e-03, x=[ 0.14362133 -1.1421349 ]
# projection step=1, g=5.442e-05, x=[ 0.14798923 -1.1370332 ]
# [(tensor([-0.9110, -1.0509], grad_fn=<AddBackward0>),)]
# projection step=0, g=6.196e-02, x=[ 0.13986127 -1.1907504 ]
# projection step=1, g=2.401e-03, x=[ 0.1690451 -1.1570863]
# projection step=2, g=4.232e-06, x=[ 0.17027079 -1.1556724 ]
# [(tensor([-0.9011, -1.0445], grad_fn=<AddBackward0>),)]
# projection step=0, g=5.577e-02, x=[ 0.14339276 -1.1878946 ]
# projection step=1, g=1.975e-03, x=[ 0.16980252 -1.1572822 ]
# projection step=2, g=2.921e-06, x=[ 0.17080875 -1.1561159 ]
# [(tensor([-0.9509, -1.0743], grad_fn=<AddBackward0>),)]
# projection step=0, g=8.464e-02, x=[ 0.12339017 -1.19766   ]
# projection step=1, g=4.232e-03, x=[ 0.16249314 -1.1534828 ]
# projection step=2, g=1.305e-05, x=[ 0.16466568 -1.1510284 ]
# [(tensor([-0.8672, -1.0108], grad_fn=<AddBackward0>),)]
# projection step=0, g=2.113e-02, x=[ 0.14357737 -1.1543446 ]
# projection step=1, g=3.036e-04, x=[ 0.15390955 -1.1423017 ]
# [(tensor([-0.9375, -1.0760], grad_fn=<AddBackward0>),)]
# projection step=0, g=8.849e-02, x=[ 0.13847366 -1.2144836 ]
# projection step=1, g=4.656e-03, x=[ 0.1792043 -1.1677371]
# projection step=2, g=1.603e-05, x=[ 0.18159935 -1.1649883 ]
# [(tensor([-0.8665, -1.0460], grad_fn=<AddBackward0>),)]
# projection step=0, g=6.317e-02, x=[ 0.17954424 -1.2255393 ]
# projection step=1, g=2.584e-03, x=[ 0.20921318 -1.1897224 ]
# projection step=2, g=5.126e-06, x=[ 0.21053508 -1.1881266 ]
# [(tensor([-0.7675, -0.9785], grad_fn=<AddBackward0>),)]
# projection step=0, g=9.545e-04, x=[ 0.21094729 -1.1894207 ]
# [(tensor([-0.7997, -1.0424], grad_fn=<AddBackward0>),)]
# projection step=0, g=7.278e-02, x=[ 0.24269325 -1.2851188 ]
# projection step=1, g=3.584e-03, x=[ 0.27640906 -1.2411714 ]
# projection step=2, g=1.073e-05, x=[ 0.27825096 -1.2387705 ]
# [(tensor([-0.6846, -0.9972], grad_fn=<AddBackward0>),)]
# projection step=0, g=4.601e-02, x=[ 0.31252673 -1.3096989 ]
# projection step=1, g=1.631e-03, x=[ 0.3340581 -1.2783389]
# projection step=2, g=2.444e-06, x=[ 0.3348793 -1.2771429]
# [(tensor([-0.6367, -0.9329], grad_fn=<AddBackward0>),)]
# projection step=0, g=-2.104e-02, x=[ 0.29614162 -1.2290012 ]
# projection step=1, g=3.901e-04, x=[ 0.28564146 -1.244385  ]
# [(tensor([-0.6923, -0.9971], grad_fn=<AddBackward0>),)]
# projection step=0, g=4.350e-02, x=[ 0.30473694 -1.3018047 ]
# projection step=1, g=1.453e-03, x=[ 0.32517812 -1.272366  ]
# projection step=2, g=1.907e-06, x=[ 0.3259096 -1.2713126]
# [(tensor([-0.5633, -0.9005], grad_fn=<AddBackward0>),)]
# projection step=0, g=-3.765e-02, x=[ 0.33726472 -1.2377983 ]
# projection step=1, g=1.369e-03, x=[ 0.31847006 -1.2678466 ]
# projection step=2, g=1.550e-06, x=[ 0.3191074 -1.2668276]
# [ 0.3191074 -1.2668276]
